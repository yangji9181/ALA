# %%
import os
import time
import glob
import pickle
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.special import expit
from sklearn.metrics import f1_score, accuracy_score
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from baseline import *

# %%
seed = 1
device = "cuda" if torch.cuda.is_available() else "cpu"

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if device=="cuda":
    torch.cuda.manual_seed(seed)

# %% [markdown]
# ## Prepare Dataset

# %%
train_G, prediction_links = pickle.load(open('input_{}.pkl'.format(1), 'rb'))

node_features = pickle.load(open('node_features.pkl', 'rb'))
text_features = np.array(list(node_features.values()))
nnodes = text_features.shape[0]

pca = PCA(n_components=100)
pca.fit(text_features)
emb_features = pca.transform(text_features)
emb_features = torch.from_numpy(emb_features).to(device).float()
    
adj = {k:{k} for k in range(nnodes)}
for node in list(train_G.nodes()):
    adj[node] = adj[node].union(list(train_G[node]))
adj = [np.sort(list(v)) for k,v in adj.items()]

# %% [markdown]
# ## Parameters

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

nlayer = 2
dims = [100]*(nlayer+1)
dropout = 0.4

lr = 0.005
weight_decay = 0.0005

patience = 50
nepoch = 10000

# %% [markdown]
# ## Link Prediction Supervised Training

# %%
X_train, X_test, y_train, y_test = train_test_split(prediction_links[:,:-1], prediction_links[:,-1])
y_train, y_test = torch.from_numpy(y_train).float().to(device), torch.from_numpy(y_test).float().to(device)

# %%
def evaluate(cos_sim, labels):
    pred = expit(cos_sim)>0.5
    f1, accuracy = f1_score(labels, pred), accuracy_score(labels, pred)
    return accuracy, f1

# %%
pdist = nn.PairwiseDistance()
edges = np.array(list(train_G.edges()))

def edge_diff(embeds):
    diff = pdist(embeds[edges[:,0]], embeds[edges[:,1]])
    return torch.mean(diff).cpu().item()

def embed_diff(embeds, prev_embeds):
    diff = pdist(embeds, prev_embeds)
    return torch.mean(diff).cpu().item()

# %%
cos = nn.CosineSimilarity()

def sup_train(model, optimizer, epoch, prev_embeds):
    t = time.time()
    model.train()
    optimizer.zero_grad()
    
    embeds = model(emb_features, adj)
    lp_input = torch.stack([embeds[X_train[:,0]], embeds[X_train[:,1]]])
    similarity = cos(lp_input[0], lp_input[1])
    loss = F.binary_cross_entropy_with_logits(similarity, y_train)
    
    accuracy, f1 = evaluate(similarity.detach().cpu().numpy(), y_train.cpu().numpy())
    curr_edge_diff = edge_diff(embeds)
    curr_embed_diff = embed_diff(embeds, prev_embeds)
    curr_input_diff = embed_diff(embeds, emb_features)
    
    loss.backward()
    optimizer.step()
    
    if (epoch+1)%1==0:
        print('Epoch: {} || Loss: {:.4f}, Acc: {:.4f}, F1: {:.4f} || Edge_diff: {:.4f}, Embed_diff: {:.4f}, Input_diff: {:.4f} || Time: {:.4f}s'
              .format(epoch, loss.item(), accuracy, f1, curr_edge_diff, curr_embed_diff, curr_input_diff, time.time()-t))
    
    return loss.item(), curr_edge_diff, curr_embed_diff, curr_input_diff, embeds

# %%
def sup_test(model):
    model.eval()
    
    embeds = model(emb_features, adj)
    lp_input = torch.stack([embeds[X_test[:,0]], embeds[X_test[:,1]]])
    similarity = cos(lp_input[0], lp_input[1])
    loss = F.binary_cross_entropy_with_logits(similarity, y_test)
    
    accuracy, f1 = evaluate(similarity.detach().cpu().numpy(), y_test.cpu().numpy())
    
    print('Loss: {:.4f}, Acc: {:.4f}, F1: {:.4f}'.format(loss.item(), accuracy, f1))

# %%
t_total = time.time()

model = GraphSAGEModel(dims=dims, dropout=dropout, nlayer=nlayer, device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

prev_embeds = emb_features
loss_values, edge_diffs, embed_diffs, input_diffs = [], [], [], []
bad_counter, best, best_epoch = 0, nepoch+1, 0
for epoch in range(nepoch):
    loss_value, curr_edge_diff, curr_embed_diff, curr_input_diff, prev_embeds = sup_train(model, optimizer, epoch, prev_embeds)
    
    loss_values.append(loss_value)
    edge_diffs.append(curr_edge_diff)
    embed_diffs.append(curr_embed_diff)
    input_diffs.append(curr_input_diff)
    
    torch.save(model.state_dict(), 'Supervised/{}.pkl'.format(epoch))
    
    if loss_values[-1] < best:
        best, best_epoch, bad_counter = loss_values[-1], epoch, 0
    else:
        bad_counter += 1
                
    if bad_counter == patience:
        break
        
    files = glob.glob('Supervised/*.pkl')
    for file in files:
        epoch_nb = int(file.split('.')[0].split('/')[-1])
        if epoch_nb < best_epoch:
            os.remove(file) 
    
files = glob.glob('Supervised/*.pkl')
for file in files:
    epoch_nb = int(file.split('.')[0].split('/')[-1])
    if epoch_nb > best_epoch:
        os.remove(file) 
        
print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))

print('Loading {}th epoch'.format(best_epoch))
model.load_state_dict(torch.load('Supervised/{}.pkl'.format(best_epoch)))

sup_test(model)
# Out:
# Epoch: 0 || Loss: 0.6857, Acc: 0.5016, F1: 0.6680 || Edge_diff: 0.3807, Embed_diff: 1.3241, Input_diff: 1.3241 || Time: 5.9874s
# Epoch: 1 || Loss: 0.6494, Acc: 0.5016, F1: 0.6680 || Edge_diff: 0.4294, Embed_diff: 0.7673, Input_diff: 1.3263 || Time: 5.8208s
# Epoch: 2 || Loss: 0.6270, Acc: 0.5016, F1: 0.6680 || Edge_diff: 0.4716, Embed_diff: 0.7326, Input_diff: 1.3273 || Time: 5.8024s
# Epoch: 3 || Loss: 0.6109, Acc: 0.5034, F1: 0.6684 || Edge_diff: 0.5179, Embed_diff: 0.7350, Input_diff: 1.3283 || Time: 5.8675s
# Epoch: 4 || Loss: 0.6029, Acc: 0.5205, F1: 0.6659 || Edge_diff: 0.5572, Embed_diff: 0.7657, Input_diff: 1.3278 || Time: 5.9309s
# Epoch: 5 || Loss: 0.5970, Acc: 0.5658, F1: 0.6797 || Edge_diff: 0.5641, Embed_diff: 0.7864, Input_diff: 1.3284 || Time: 5.9105s
# Epoch: 6 || Loss: 0.5957, Acc: 0.6090, F1: 0.6887 || Edge_diff: 0.5604, Embed_diff: 0.7902, Input_diff: 1.3298 || Time: 5.7700s
# Epoch: 7 || Loss: 0.5917, Acc: 0.6616, F1: 0.7214 || Edge_diff: 0.5517, Embed_diff: 0.7778, Input_diff: 1.3284 || Time: 5.9324s
# Epoch: 8 || Loss: 0.5900, Acc: 0.6880, F1: 0.7366 || Edge_diff: 0.5416, Embed_diff: 0.7382, Input_diff: 1.3277 || Time: 5.7946s
# Epoch: 9 || Loss: 0.5884, Acc: 0.7097, F1: 0.7407 || Edge_diff: 0.5276, Embed_diff: 0.7240, Input_diff: 1.3261 || Time: 5.7865s
# Epoch: 10 || Loss: 0.5855, Acc: 0.7369, F1: 0.7557 || Edge_diff: 0.5213, Embed_diff: 0.7128, Input_diff: 1.3232 || Time: 5.8159s
# Epoch: 11 || Loss: 0.5854, Acc: 0.7431, F1: 0.7560 || Edge_diff: 0.5061, Embed_diff: 0.6902, Input_diff: 1.3233 || Time: 5.8219s
# Epoch: 12 || Loss: 0.5853, Acc: 0.7395, F1: 0.7512 || Edge_diff: 0.5004, Embed_diff: 0.6737, Input_diff: 1.3206 || Time: 5.8703s
# Epoch: 13 || Loss: 0.5820, Acc: 0.7589, F1: 0.7648 || Edge_diff: 0.4951, Embed_diff: 0.6650, Input_diff: 1.3205 || Time: 5.9247s
# Epoch: 14 || Loss: 0.5825, Acc: 0.7680, F1: 0.7701 || Edge_diff: 0.4922, Embed_diff: 0.6595, Input_diff: 1.3197 || Time: 5.7950s
# Epoch: 15 || Loss: 0.5819, Acc: 0.7633, F1: 0.7659 || Edge_diff: 0.4947, Embed_diff: 0.6595, Input_diff: 1.3193 || Time: 5.8794s
# Epoch: 16 || Loss: 0.5823, Acc: 0.7654, F1: 0.7675 || Edge_diff: 0.4880, Embed_diff: 0.6500, Input_diff: 1.3186 || Time: 5.8950s
# Epoch: 17 || Loss: 0.5807, Acc: 0.7706, F1: 0.7709 || Edge_diff: 0.4896, Embed_diff: 0.6482, Input_diff: 1.3194 || Time: 5.8363s
# Epoch: 18 || Loss: 0.5796, Acc: 0.7771, F1: 0.7761 || Edge_diff: 0.4963, Embed_diff: 0.6475, Input_diff: 1.3206 || Time: 5.9026s
# Epoch: 19 || Loss: 0.5784, Acc: 0.7773, F1: 0.7766 || Edge_diff: 0.4940, Embed_diff: 0.6432, Input_diff: 1.3187 || Time: 5.9257s
# Epoch: 20 || Loss: 0.5774, Acc: 0.7781, F1: 0.7755 || Edge_diff: 0.4912, Embed_diff: 0.6480, Input_diff: 1.3189 || Time: 5.8964s
# Epoch: 21 || Loss: 0.5769, Acc: 0.7838, F1: 0.7826 || Edge_diff: 0.4869, Embed_diff: 0.6311, Input_diff: 1.3211 || Time: 5.9222s
# Epoch: 22 || Loss: 0.5762, Acc: 0.7794, F1: 0.7790 || Edge_diff: 0.4831, Embed_diff: 0.6235, Input_diff: 1.3210 || Time: 5.8344s
# Epoch: 23 || Loss: 0.5769, Acc: 0.7776, F1: 0.7779 || Edge_diff: 0.4843, Embed_diff: 0.6214, Input_diff: 1.3202 || Time: 5.7897s
# Epoch: 24 || Loss: 0.5743, Acc: 0.7882, F1: 0.7890 || Edge_diff: 0.4844, Embed_diff: 0.6158, Input_diff: 1.3204 || Time: 5.8769s
# Epoch: 25 || Loss: 0.5740, Acc: 0.7918, F1: 0.7910 || Edge_diff: 0.4847, Embed_diff: 0.6195, Input_diff: 1.3212 || Time: 5.9883s
# Epoch: 26 || Loss: 0.5733, Acc: 0.7941, F1: 0.7928 || Edge_diff: 0.4791, Embed_diff: 0.6147, Input_diff: 1.3197 || Time: 5.8019s
# Epoch: 27 || Loss: 0.5725, Acc: 0.7967, F1: 0.7958 || Edge_diff: 0.4760, Embed_diff: 0.5999, Input_diff: 1.3219 || Time: 5.9595s
# Epoch: 28 || Loss: 0.5723, Acc: 0.7944, F1: 0.7924 || Edge_diff: 0.4767, Embed_diff: 0.6020, Input_diff: 1.3199 || Time: 5.8326s
# Epoch: 29 || Loss: 0.5704, Acc: 0.8055, F1: 0.8038 || Edge_diff: 0.4729, Embed_diff: 0.6006, Input_diff: 1.3196 || Time: 5.8222s
# Epoch: 30 || Loss: 0.5708, Acc: 0.8089, F1: 0.8049 || Edge_diff: 0.4749, Embed_diff: 0.5993, Input_diff: 1.3186 || Time: 5.8999s
# Epoch: 31 || Loss: 0.5687, Acc: 0.8004, F1: 0.7995 || Edge_diff: 0.4724, Embed_diff: 0.5987, Input_diff: 1.3201 || Time: 5.8417s
# Epoch: 32 || Loss: 0.5694, Acc: 0.8027, F1: 0.8007 || Edge_diff: 0.4729, Embed_diff: 0.5940, Input_diff: 1.3184 || Time: 5.7770s
# Epoch: 33 || Loss: 0.5697, Acc: 0.8048, F1: 0.8037 || Edge_diff: 0.4755, Embed_diff: 0.5938, Input_diff: 1.3203 || Time: 5.7655s
# Epoch: 34 || Loss: 0.5679, Acc: 0.8086, F1: 0.8081 || Edge_diff: 0.4631, Embed_diff: 0.5885, Input_diff: 1.3198 || Time: 5.8498s
# Epoch: 35 || Loss: 0.5668, Acc: 0.8107, F1: 0.8072 || Edge_diff: 0.4695, Embed_diff: 0.5875, Input_diff: 1.3198 || Time: 5.8707s
# Epoch: 36 || Loss: 0.5665, Acc: 0.8149, F1: 0.8122 || Edge_diff: 0.4628, Embed_diff: 0.5849, Input_diff: 1.3194 || Time: 5.8392s
# Epoch: 37 || Loss: 0.5648, Acc: 0.8276, F1: 0.8227 || Edge_diff: 0.4593, Embed_diff: 0.5764, Input_diff: 1.3181 || Time: 5.9226s
# Epoch: 38 || Loss: 0.5652, Acc: 0.8213, F1: 0.8186 || Edge_diff: 0.4578, Embed_diff: 0.5744, Input_diff: 1.3194 || Time: 5.7489s
# Epoch: 39 || Loss: 0.5676, Acc: 0.8141, F1: 0.8090 || Edge_diff: 0.4645, Embed_diff: 0.5594, Input_diff: 1.3201 || Time: 5.9358s
# Epoch: 40 || Loss: 0.5652, Acc: 0.8252, F1: 0.8190 || Edge_diff: 0.4605, Embed_diff: 0.5636, Input_diff: 1.3166 || Time: 5.8621s
# Epoch: 41 || Loss: 0.5655, Acc: 0.8270, F1: 0.8204 || Edge_diff: 0.4580, Embed_diff: 0.5569, Input_diff: 1.3191 || Time: 5.8494s
# Epoch: 42 || Loss: 0.5656, Acc: 0.8286, F1: 0.8219 || Edge_diff: 0.4549, Embed_diff: 0.5518, Input_diff: 1.3174 || Time: 5.8357s
# Epoch: 43 || Loss: 0.5668, Acc: 0.8237, F1: 0.8170 || Edge_diff: 0.4582, Embed_diff: 0.5579, Input_diff: 1.3170 || Time: 5.8380s
# Epoch: 44 || Loss: 0.5648, Acc: 0.8338, F1: 0.8270 || Edge_diff: 0.4520, Embed_diff: 0.5499, Input_diff: 1.3167 || Time: 5.7600s
# Epoch: 45 || Loss: 0.5658, Acc: 0.8299, F1: 0.8228 || Edge_diff: 0.4498, Embed_diff: 0.5509, Input_diff: 1.3166 || Time: 5.8366s
# Epoch: 46 || Loss: 0.5643, Acc: 0.8283, F1: 0.8222 || Edge_diff: 0.4546, Embed_diff: 0.5506, Input_diff: 1.3176 || Time: 5.7546s
# Epoch: 47 || Loss: 0.5660, Acc: 0.8286, F1: 0.8215 || Edge_diff: 0.4519, Embed_diff: 0.5540, Input_diff: 1.3164 || Time: 5.8487s
# Epoch: 48 || Loss: 0.5659, Acc: 0.8175, F1: 0.8131 || Edge_diff: 0.4533, Embed_diff: 0.5490, Input_diff: 1.3169 || Time: 5.8532s
# Epoch: 49 || Loss: 0.5647, Acc: 0.8237, F1: 0.8187 || Edge_diff: 0.4519, Embed_diff: 0.5432, Input_diff: 1.3168 || Time: 5.8354s
# Epoch: 50 || Loss: 0.5640, Acc: 0.8265, F1: 0.8181 || Edge_diff: 0.4529, Embed_diff: 0.5540, Input_diff: 1.3157 || Time: 5.7901s
# Epoch: 51 || Loss: 0.5641, Acc: 0.8384, F1: 0.8306 || Edge_diff: 0.4513, Embed_diff: 0.5469, Input_diff: 1.3173 || Time: 5.8275s
# Epoch: 52 || Loss: 0.5639, Acc: 0.8338, F1: 0.8242 || Edge_diff: 0.4504, Embed_diff: 0.5474, Input_diff: 1.3164 || Time: 5.8023s
# Epoch: 53 || Loss: 0.5646, Acc: 0.8413, F1: 0.8333 || Edge_diff: 0.4564, Embed_diff: 0.5389, Input_diff: 1.3172 || Time: 5.8145s
# Epoch: 54 || Loss: 0.5644, Acc: 0.8288, F1: 0.8200 || Edge_diff: 0.4550, Embed_diff: 0.5475, Input_diff: 1.3161 || Time: 5.8822s
# Epoch: 55 || Loss: 0.5647, Acc: 0.8384, F1: 0.8284 || Edge_diff: 0.4512, Embed_diff: 0.5437, Input_diff: 1.3139 || Time: 5.8496s
# Epoch: 56 || Loss: 0.5627, Acc: 0.8418, F1: 0.8331 || Edge_diff: 0.4510, Embed_diff: 0.5399, Input_diff: 1.3146 || Time: 5.7919s
# Epoch: 57 || Loss: 0.5642, Acc: 0.8389, F1: 0.8280 || Edge_diff: 0.4472, Embed_diff: 0.5475, Input_diff: 1.3136 || Time: 5.7727s
# Epoch: 58 || Loss: 0.5639, Acc: 0.8410, F1: 0.8323 || Edge_diff: 0.4448, Embed_diff: 0.5390, Input_diff: 1.3172 || Time: 5.8472s
# Epoch: 59 || Loss: 0.5649, Acc: 0.8369, F1: 0.8267 || Edge_diff: 0.4445, Embed_diff: 0.5421, Input_diff: 1.3134 || Time: 5.8376s
# Epoch: 60 || Loss: 0.5622, Acc: 0.8431, F1: 0.8323 || Edge_diff: 0.4381, Embed_diff: 0.5281, Input_diff: 1.3134 || Time: 5.8630s
# Epoch: 61 || Loss: 0.5622, Acc: 0.8446, F1: 0.8338 || Edge_diff: 0.4427, Embed_diff: 0.5247, Input_diff: 1.3134 || Time: 5.8435s
# Epoch: 62 || Loss: 0.5618, Acc: 0.8415, F1: 0.8324 || Edge_diff: 0.4412, Embed_diff: 0.5313, Input_diff: 1.3150 || Time: 5.8452s
# Epoch: 63 || Loss: 0.5609, Acc: 0.8475, F1: 0.8378 || Edge_diff: 0.4425, Embed_diff: 0.5239, Input_diff: 1.3152 || Time: 5.8706s
# Epoch: 64 || Loss: 0.5603, Acc: 0.8514, F1: 0.8418 || Edge_diff: 0.4395, Embed_diff: 0.5271, Input_diff: 1.3146 || Time: 5.8075s
# Epoch: 65 || Loss: 0.5610, Acc: 0.8472, F1: 0.8379 || Edge_diff: 0.4389, Embed_diff: 0.5266, Input_diff: 1.3137 || Time: 5.8396s
# Epoch: 66 || Loss: 0.5606, Acc: 0.8449, F1: 0.8357 || Edge_diff: 0.4389, Embed_diff: 0.5161, Input_diff: 1.3149 || Time: 5.8875s
# Epoch: 67 || Loss: 0.5608, Acc: 0.8379, F1: 0.8299 || Edge_diff: 0.4361, Embed_diff: 0.5113, Input_diff: 1.3136 || Time: 5.8110s
# Epoch: 68 || Loss: 0.5619, Acc: 0.8389, F1: 0.8296 || Edge_diff: 0.4386, Embed_diff: 0.5207, Input_diff: 1.3137 || Time: 5.9574s
# Epoch: 69 || Loss: 0.5604, Acc: 0.8431, F1: 0.8352 || Edge_diff: 0.4405, Embed_diff: 0.5287, Input_diff: 1.3160 || Time: 5.8098s
# Epoch: 70 || Loss: 0.5600, Acc: 0.8431, F1: 0.8346 || Edge_diff: 0.4377, Embed_diff: 0.5217, Input_diff: 1.3143 || Time: 5.8890s
# Epoch: 71 || Loss: 0.5605, Acc: 0.8475, F1: 0.8376 || Edge_diff: 0.4374, Embed_diff: 0.5308, Input_diff: 1.3129 || Time: 5.8698s
# Epoch: 72 || Loss: 0.5616, Acc: 0.8441, F1: 0.8326 || Edge_diff: 0.4423, Embed_diff: 0.5331, Input_diff: 1.3139 || Time: 5.7671s
# Epoch: 73 || Loss: 0.5603, Acc: 0.8553, F1: 0.8446 || Edge_diff: 0.4389, Embed_diff: 0.5314, Input_diff: 1.3133 || Time: 5.8879s
# Epoch: 74 || Loss: 0.5614, Acc: 0.8488, F1: 0.8374 || Edge_diff: 0.4330, Embed_diff: 0.5305, Input_diff: 1.3122 || Time: 5.9677s
# Epoch: 75 || Loss: 0.5603, Acc: 0.8532, F1: 0.8432 || Edge_diff: 0.4333, Embed_diff: 0.5251, Input_diff: 1.3135 || Time: 5.9244s
# Epoch: 76 || Loss: 0.5602, Acc: 0.8516, F1: 0.8414 || Edge_diff: 0.4301, Embed_diff: 0.5208, Input_diff: 1.3117 || Time: 5.8245s
# Epoch: 77 || Loss: 0.5608, Acc: 0.8444, F1: 0.8341 || Edge_diff: 0.4297, Embed_diff: 0.5232, Input_diff: 1.3121 || Time: 5.8306s
# Epoch: 78 || Loss: 0.5592, Acc: 0.8490, F1: 0.8393 || Edge_diff: 0.4339, Embed_diff: 0.5134, Input_diff: 1.3130 || Time: 5.7857s
# Epoch: 79 || Loss: 0.5589, Acc: 0.8506, F1: 0.8420 || Edge_diff: 0.4259, Embed_diff: 0.5152, Input_diff: 1.3120 || Time: 5.8807s
# Epoch: 80 || Loss: 0.5595, Acc: 0.8480, F1: 0.8377 || Edge_diff: 0.4302, Embed_diff: 0.5194, Input_diff: 1.3129 || Time: 5.8631s
# Epoch: 81 || Loss: 0.5598, Acc: 0.8558, F1: 0.8451 || Edge_diff: 0.4311, Embed_diff: 0.5065, Input_diff: 1.3124 || Time: 5.8429s
# Epoch: 82 || Loss: 0.5593, Acc: 0.8568, F1: 0.8458 || Edge_diff: 0.4322, Embed_diff: 0.5068, Input_diff: 1.3114 || Time: 5.8950s
# Epoch: 83 || Loss: 0.5591, Acc: 0.8553, F1: 0.8445 || Edge_diff: 0.4311, Embed_diff: 0.5078, Input_diff: 1.3106 || Time: 5.8328s
# Epoch: 84 || Loss: 0.5593, Acc: 0.8555, F1: 0.8446 || Edge_diff: 0.4318, Embed_diff: 0.5154, Input_diff: 1.3122 || Time: 5.8171s
# Epoch: 85 || Loss: 0.5606, Acc: 0.8524, F1: 0.8410 || Edge_diff: 0.4365, Embed_diff: 0.5110, Input_diff: 1.3119 || Time: 5.8107s
# Epoch: 86 || Loss: 0.5595, Acc: 0.8516, F1: 0.8405 || Edge_diff: 0.4347, Embed_diff: 0.5126, Input_diff: 1.3097 || Time: 5.8285s
# Epoch: 87 || Loss: 0.5606, Acc: 0.8553, F1: 0.8435 || Edge_diff: 0.4314, Embed_diff: 0.5030, Input_diff: 1.3117 || Time: 5.8916s
# Epoch: 88 || Loss: 0.5591, Acc: 0.8607, F1: 0.8494 || Edge_diff: 0.4226, Embed_diff: 0.5061, Input_diff: 1.3101 || Time: 5.7812s
# Epoch: 89 || Loss: 0.5603, Acc: 0.8534, F1: 0.8421 || Edge_diff: 0.4279, Embed_diff: 0.5083, Input_diff: 1.3072 || Time: 5.8293s
# Epoch: 90 || Loss: 0.5598, Acc: 0.8571, F1: 0.8453 || Edge_diff: 0.4305, Embed_diff: 0.5125, Input_diff: 1.3071 || Time: 5.7728s
# Epoch: 91 || Loss: 0.5598, Acc: 0.8604, F1: 0.8491 || Edge_diff: 0.4238, Embed_diff: 0.5079, Input_diff: 1.3078 || Time: 5.8120s
# Epoch: 92 || Loss: 0.5601, Acc: 0.8589, F1: 0.8470 || Edge_diff: 0.4280, Embed_diff: 0.5128, Input_diff: 1.3081 || Time: 5.8226s
# Epoch: 93 || Loss: 0.5585, Acc: 0.8540, F1: 0.8425 || Edge_diff: 0.4320, Embed_diff: 0.5102, Input_diff: 1.3103 || Time: 5.8496s
# Epoch: 94 || Loss: 0.5585, Acc: 0.8617, F1: 0.8508 || Edge_diff: 0.4356, Embed_diff: 0.5035, Input_diff: 1.3101 || Time: 5.8107s
# Epoch: 95 || Loss: 0.5618, Acc: 0.8498, F1: 0.8385 || Edge_diff: 0.4360, Embed_diff: 0.5164, Input_diff: 1.3096 || Time: 5.8462s
# Epoch: 96 || Loss: 0.5612, Acc: 0.8534, F1: 0.8407 || Edge_diff: 0.4378, Embed_diff: 0.5198, Input_diff: 1.3105 || Time: 5.8302s
# Epoch: 97 || Loss: 0.5617, Acc: 0.8439, F1: 0.8321 || Edge_diff: 0.4359, Embed_diff: 0.5263, Input_diff: 1.3119 || Time: 5.7002s
# Epoch: 98 || Loss: 0.5609, Acc: 0.8498, F1: 0.8392 || Edge_diff: 0.4356, Embed_diff: 0.5099, Input_diff: 1.3126 || Time: 5.8143s
# Epoch: 99 || Loss: 0.5605, Acc: 0.8509, F1: 0.8393 || Edge_diff: 0.4297, Embed_diff: 0.5025, Input_diff: 1.3119 || Time: 5.8554s
# Epoch: 100 || Loss: 0.5602, Acc: 0.8498, F1: 0.8380 || Edge_diff: 0.4277, Embed_diff: 0.4997, Input_diff: 1.3102 || Time: 5.8062s
# Epoch: 101 || Loss: 0.5646, Acc: 0.8405, F1: 0.8268 || Edge_diff: 0.4483, Embed_diff: 0.5109, Input_diff: 1.3116 || Time: 5.8333s
# Epoch: 102 || Loss: 0.5596, Acc: 0.8511, F1: 0.8409 || Edge_diff: 0.4285, Embed_diff: 0.5066, Input_diff: 1.3138 || Time: 5.8002s
# Epoch: 103 || Loss: 0.5584, Acc: 0.8408, F1: 0.8329 || Edge_diff: 0.4311, Embed_diff: 0.5124, Input_diff: 1.3140 || Time: 5.8108s
# Epoch: 104 || Loss: 0.5599, Acc: 0.8477, F1: 0.8379 || Edge_diff: 0.4344, Embed_diff: 0.5171, Input_diff: 1.3144 || Time: 5.8961s
# Epoch: 105 || Loss: 0.5607, Acc: 0.8389, F1: 0.8298 || Edge_diff: 0.4326, Embed_diff: 0.5116, Input_diff: 1.3137 || Time: 5.8611s
# Epoch: 106 || Loss: 0.5598, Acc: 0.8511, F1: 0.8395 || Edge_diff: 0.4385, Embed_diff: 0.5105, Input_diff: 1.3121 || Time: 5.8169s
# Epoch: 107 || Loss: 0.5596, Acc: 0.8540, F1: 0.8427 || Edge_diff: 0.4291, Embed_diff: 0.5274, Input_diff: 1.3091 || Time: 5.8297s
# Epoch: 108 || Loss: 0.5605, Acc: 0.8524, F1: 0.8403 || Edge_diff: 0.4279, Embed_diff: 0.5162, Input_diff: 1.3094 || Time: 5.7975s
# Epoch: 109 || Loss: 0.5605, Acc: 0.8547, F1: 0.8410 || Edge_diff: 0.4300, Embed_diff: 0.5158, Input_diff: 1.3052 || Time: 5.8619s
# Epoch: 110 || Loss: 0.5623, Acc: 0.8483, F1: 0.8337 || Edge_diff: 0.4304, Embed_diff: 0.5145, Input_diff: 1.3056 || Time: 5.7950s
# Epoch: 111 || Loss: 0.5636, Acc: 0.8462, F1: 0.8342 || Edge_diff: 0.4277, Embed_diff: 0.5199, Input_diff: 1.3064 || Time: 5.9153s
# Epoch: 112 || Loss: 0.5624, Acc: 0.8527, F1: 0.8397 || Edge_diff: 0.4289, Embed_diff: 0.5105, Input_diff: 1.3047 || Time: 5.8237s
# Epoch: 113 || Loss: 0.5619, Acc: 0.8503, F1: 0.8361 || Edge_diff: 0.4277, Embed_diff: 0.5101, Input_diff: 1.3045 || Time: 5.8297s
# Epoch: 114 || Loss: 0.5619, Acc: 0.8501, F1: 0.8364 || Edge_diff: 0.4291, Embed_diff: 0.5119, Input_diff: 1.3059 || Time: 5.8306s
# Epoch: 115 || Loss: 0.5639, Acc: 0.8428, F1: 0.8295 || Edge_diff: 0.4301, Embed_diff: 0.5116, Input_diff: 1.3059 || Time: 5.8108s
# Epoch: 116 || Loss: 0.5629, Acc: 0.8472, F1: 0.8347 || Edge_diff: 0.4293, Embed_diff: 0.5032, Input_diff: 1.3067 || Time: 5.8633s
# Epoch: 117 || Loss: 0.5646, Acc: 0.8389, F1: 0.8249 || Edge_diff: 0.4267, Embed_diff: 0.5049, Input_diff: 1.3066 || Time: 5.8210s
# Epoch: 118 || Loss: 0.5602, Acc: 0.8542, F1: 0.8424 || Edge_diff: 0.4308, Embed_diff: 0.5038, Input_diff: 1.3097 || Time: 5.8451s
# Epoch: 119 || Loss: 0.5617, Acc: 0.8441, F1: 0.8327 || Edge_diff: 0.4350, Embed_diff: 0.5187, Input_diff: 1.3091 || Time: 5.8137s
# Epoch: 120 || Loss: 0.5614, Acc: 0.8496, F1: 0.8367 || Edge_diff: 0.4378, Embed_diff: 0.5182, Input_diff: 1.3098 || Time: 5.7932s
# Epoch: 121 || Loss: 0.5638, Acc: 0.8426, F1: 0.8278 || Edge_diff: 0.4362, Embed_diff: 0.5293, Input_diff: 1.3066 || Time: 5.8124s
# Epoch: 122 || Loss: 0.5610, Acc: 0.8501, F1: 0.8376 || Edge_diff: 0.4295, Embed_diff: 0.5180, Input_diff: 1.3103 || Time: 5.8334s
# Epoch: 123 || Loss: 0.5619, Acc: 0.8421, F1: 0.8287 || Edge_diff: 0.4280, Embed_diff: 0.5119, Input_diff: 1.3077 || Time: 5.9130s
# Epoch: 124 || Loss: 0.5626, Acc: 0.8477, F1: 0.8344 || Edge_diff: 0.4258, Embed_diff: 0.5057, Input_diff: 1.3087 || Time: 5.8604s
# Epoch: 125 || Loss: 0.5618, Acc: 0.8493, F1: 0.8363 || Edge_diff: 0.4247, Embed_diff: 0.4959, Input_diff: 1.3110 || Time: 5.8388s
# Epoch: 126 || Loss: 0.5631, Acc: 0.8475, F1: 0.8336 || Edge_diff: 0.4240, Embed_diff: 0.5038, Input_diff: 1.3112 || Time: 5.8404s
# Epoch: 127 || Loss: 0.5620, Acc: 0.8454, F1: 0.8337 || Edge_diff: 0.4256, Embed_diff: 0.5079, Input_diff: 1.3155 || Time: 5.8088s
# Epoch: 128 || Loss: 0.5636, Acc: 0.8413, F1: 0.8296 || Edge_diff: 0.4340, Embed_diff: 0.5092, Input_diff: 1.3150 || Time: 5.8363s
# Epoch: 129 || Loss: 0.5611, Acc: 0.8496, F1: 0.8376 || Edge_diff: 0.4228, Embed_diff: 0.5195, Input_diff: 1.3087 || Time: 5.7965s
# Epoch: 130 || Loss: 0.5625, Acc: 0.8503, F1: 0.8373 || Edge_diff: 0.4265, Embed_diff: 0.5110, Input_diff: 1.3064 || Time: 5.7788s
# Epoch: 131 || Loss: 0.5619, Acc: 0.8529, F1: 0.8396 || Edge_diff: 0.4264, Embed_diff: 0.5171, Input_diff: 1.3056 || Time: 5.9145s
# Epoch: 132 || Loss: 0.5613, Acc: 0.8470, F1: 0.8339 || Edge_diff: 0.4306, Embed_diff: 0.5149, Input_diff: 1.3075 || Time: 5.7778s
# Epoch: 133 || Loss: 0.5611, Acc: 0.8503, F1: 0.8373 || Edge_diff: 0.4264, Embed_diff: 0.5086, Input_diff: 1.3066 || Time: 5.7968s
# Epoch: 134 || Loss: 0.5615, Acc: 0.8485, F1: 0.8369 || Edge_diff: 0.4249, Embed_diff: 0.5186, Input_diff: 1.3076 || Time: 5.9154s
# Epoch: 135 || Loss: 0.5631, Acc: 0.8428, F1: 0.8299 || Edge_diff: 0.4275, Embed_diff: 0.5200, Input_diff: 1.3069 || Time: 5.8719s
# Epoch: 136 || Loss: 0.5636, Acc: 0.8366, F1: 0.8225 || Edge_diff: 0.4245, Embed_diff: 0.5169, Input_diff: 1.3081 || Time: 5.8384s
# Epoch: 137 || Loss: 0.5627, Acc: 0.8452, F1: 0.8315 || Edge_diff: 0.4240, Embed_diff: 0.5095, Input_diff: 1.3077 || Time: 5.8196s
# Epoch: 138 || Loss: 0.5613, Acc: 0.8514, F1: 0.8377 || Edge_diff: 0.4244, Embed_diff: 0.5141, Input_diff: 1.3089 || Time: 5.8549s
# Epoch: 139 || Loss: 0.5647, Acc: 0.8421, F1: 0.8272 || Edge_diff: 0.4277, Embed_diff: 0.5278, Input_diff: 1.3088 || Time: 5.8690s
# Epoch: 140 || Loss: 0.5628, Acc: 0.8493, F1: 0.8350 || Edge_diff: 0.4240, Embed_diff: 0.5240, Input_diff: 1.3120 || Time: 5.8666s
# Epoch: 141 || Loss: 0.5642, Acc: 0.8364, F1: 0.8227 || Edge_diff: 0.4258, Embed_diff: 0.5227, Input_diff: 1.3115 || Time: 5.8330s
# Epoch: 142 || Loss: 0.5632, Acc: 0.8446, F1: 0.8310 || Edge_diff: 0.4186, Embed_diff: 0.5105, Input_diff: 1.3074 || Time: 5.7985s
# Epoch: 143 || Loss: 0.5619, Acc: 0.8506, F1: 0.8370 || Edge_diff: 0.4161, Embed_diff: 0.5045, Input_diff: 1.3104 || Time: 5.8341s
# Epoch: 144 || Loss: 0.5642, Acc: 0.8488, F1: 0.8346 || Edge_diff: 0.4188, Embed_diff: 0.5126, Input_diff: 1.3092 || Time: 5.7558s
# Epoch: 145 || Loss: 0.5608, Acc: 0.8545, F1: 0.8411 || Edge_diff: 0.4156, Embed_diff: 0.5087, Input_diff: 1.3049 || Time: 5.7865s
# Epoch: 146 || Loss: 0.5611, Acc: 0.8483, F1: 0.8353 || Edge_diff: 0.4166, Embed_diff: 0.5021, Input_diff: 1.3083 || Time: 5.8061s
# Epoch: 147 || Loss: 0.5598, Acc: 0.8529, F1: 0.8412 || Edge_diff: 0.4147, Embed_diff: 0.5091, Input_diff: 1.3102 || Time: 5.8802s
# Epoch: 148 || Loss: 0.5614, Acc: 0.8421, F1: 0.8289 || Edge_diff: 0.4233, Embed_diff: 0.5073, Input_diff: 1.3104 || Time: 5.8498s
# Epoch: 149 || Loss: 0.5633, Acc: 0.8454, F1: 0.8313 || Edge_diff: 0.4309, Embed_diff: 0.5112, Input_diff: 1.3083 || Time: 5.7557s
# Epoch: 150 || Loss: 0.5627, Acc: 0.8405, F1: 0.8283 || Edge_diff: 0.4260, Embed_diff: 0.5035, Input_diff: 1.3107 || Time: 5.7319s
# Epoch: 151 || Loss: 0.5615, Acc: 0.8423, F1: 0.8303 || Edge_diff: 0.4255, Embed_diff: 0.5095, Input_diff: 1.3099 || Time: 5.7059s
# Epoch: 152 || Loss: 0.5640, Acc: 0.8408, F1: 0.8276 || Edge_diff: 0.4285, Embed_diff: 0.5079, Input_diff: 1.3101 || Time: 5.8504s
# Epoch: 153 || Loss: 0.5619, Acc: 0.8446, F1: 0.8317 || Edge_diff: 0.4276, Embed_diff: 0.5127, Input_diff: 1.3081 || Time: 5.7900s
# Optimization Finished!
# Total time elapsed: 902.1253s
# Loading 103th epoch
# Loss: 0.5831, Acc: 0.7857, F1: 0.7727

# %%
plt.plot(loss_values)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Curve')
# Out:
# Text(0.5, 1.0, 'Training Loss Curve')

# %%
plt.plot(edge_diffs)
plt.xlabel('Epoch')
plt.ylabel('Edge-wise Distance')
plt.title('Training Edge-wise Distance Curve')
# Out:
# Text(0.5, 1.0, 'Training Edge-wise Distance Curve')

# %%
plt.plot(embed_diffs)
plt.xlabel('Epoch')
plt.ylabel('Change in Last/Curr Embedding')
plt.title('Change in Embedding Curve')
# Out:
# Text(0.5, 1.0, 'Change in Embedding Curve')

# %%
plt.plot(input_diffs)
plt.xlabel('Epoch')
plt.ylabel('Change in Input/Output')
plt.title('Change in Input/Output Curve')
# Out:
# Text(0.5, 1.0, 'Change in Input/Output Curve')

# %%
pickle.dump((loss_values, edge_diffs, embed_diffs, input_diffs), open('supervised_experiments.pkl', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)
