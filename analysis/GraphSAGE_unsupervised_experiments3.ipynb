# %%
import os
import time
import glob
import pickle
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.special import expit
from sklearn.metrics import f1_score, accuracy_score
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from baseline import *

# %%
seed = 1
device = "cuda" if torch.cuda.is_available() else "cpu"

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if device=="cuda":
    torch.cuda.manual_seed(seed)

# %% [markdown]
# ## Prepare Dataset

# %%
train_G, prediction_links = pickle.load(open('input_{}.pkl'.format(1), 'rb'))

node_features = pickle.load(open('node_features.pkl', 'rb'))
text_features = np.array(list(node_features.values()))
nnodes = text_features.shape[0]

pca = PCA(n_components=100)
pca.fit(text_features)
emb_features = pca.transform(text_features)
emb_features = torch.from_numpy(emb_features).to(device).float()
    
adj = {k:{k} for k in range(nnodes)}
for node in list(train_G.nodes()):
    adj[node] = adj[node].union(list(train_G[node]))
adj = [np.sort(list(v)) for k,v in adj.items()]

# %% [markdown]
# ## Parameters

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

nlayer = 2
dims = [100]*(nlayer+1)
dropout = 0.4

lr = 0.005
weight_decay = 0.0005

nepoch = 100

# %% [markdown]
# ## Evaluation

# %%
cos = nn.CosineSimilarity()

def lp_eval(embeds):
    lp_input = torch.stack([embeds[prediction_links[:,0]], embeds[prediction_links[:,1]]])
    similarity = cos(lp_input[0], lp_input[1]).detach().cpu().numpy()
    pred = expit(similarity)>0.5
    labels = prediction_links[:,-1]
    f1, accuracy = f1_score(labels, pred), accuracy_score(labels, pred)
    return accuracy, f1

# %%
pdist = nn.PairwiseDistance()
edges = np.array(list(train_G.edges()))

def edge_diff(embeds):
    diff = pdist(embeds[edges[:,0]], embeds[edges[:,1]])
    return torch.mean(diff).cpu().item()

# %% [markdown]
# ## Unsupervised Training, Input = initial features, Loss = - (output embedding - input embedding)

# %%
def unsup1(model, optimizer, epoch, prev_embeds):
    t = time.time()
    model.train()
    optimizer.zero_grad()
    
    embeds = model(emb_features, adj)
    loss = -torch.mean(pdist(embeds, emb_features))
    
    loss.backward()
    optimizer.step()
    
    accuracy, f1 = lp_eval(embeds)    
    curr_edge_diff = edge_diff(embeds)
    curr_embed_diff = torch.mean(pdist(embeds, prev_embeds)).cpu().item()
    curr_input_diff = -loss.item()   
    
    
    if (epoch+1)%1==0:
        print('Epoch: {} || Acc: {:.4f}, F1: {:.4f} || Edge_diff: {:.4f}, Embed_diff: {:.4f}, Input_diff: {:.4f} || Time: {:.4f}s'
              .format(epoch, accuracy, f1, curr_edge_diff, curr_embed_diff, curr_input_diff, time.time()-t))
    
    return accuracy, curr_edge_diff, curr_embed_diff, curr_input_diff, embeds

# %%
t_total = time.time()

model = GraphSAGEModel(dims=dims, dropout=dropout, nlayer=nlayer, device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

prev_embeds = emb_features
acc_values, edge_diffs, embed_diffs, input_diffs = [], [], [], []
for epoch in range(nepoch):
    acc_value, curr_edge_diff, curr_embed_diff, curr_input_diff, prev_embeds = unsup1(model, optimizer, epoch, prev_embeds.detach())
    
    acc_values.append(acc_value)
    edge_diffs.append(curr_edge_diff)
    embed_diffs.append(curr_embed_diff)
    input_diffs.append(curr_input_diff)
    
torch.save(model.state_dict(), 'Unsupervised/Version_3.pkl')  
        
print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
# Out:
# Epoch: 0 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3807, Embed_diff: 1.3241, Input_diff: 1.3241 || Time: 5.8954s
# Epoch: 1 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3810, Embed_diff: 0.6418, Input_diff: 1.3642 || Time: 5.7521s
# Epoch: 2 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4105, Embed_diff: 0.6627, Input_diff: 1.4067 || Time: 5.8276s
# Epoch: 3 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4246, Embed_diff: 0.7022, Input_diff: 1.4477 || Time: 5.7471s
# Epoch: 4 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4172, Embed_diff: 0.6906, Input_diff: 1.4817 || Time: 5.7863s
# Epoch: 5 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3947, Embed_diff: 0.6337, Input_diff: 1.5045 || Time: 5.8297s
# Epoch: 6 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3815, Embed_diff: 0.5751, Input_diff: 1.5217 || Time: 5.7883s
# Epoch: 7 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3721, Embed_diff: 0.5411, Input_diff: 1.5327 || Time: 5.8084s
# Epoch: 8 || Acc: 0.5006, F1: 0.6669 || Edge_diff: 0.3785, Embed_diff: 0.5039, Input_diff: 1.5407 || Time: 5.8122s
# Epoch: 9 || Acc: 0.5004, F1: 0.6668 || Edge_diff: 0.3847, Embed_diff: 0.4947, Input_diff: 1.5478 || Time: 5.7386s
# Epoch: 10 || Acc: 0.5014, F1: 0.6673 || Edge_diff: 0.3937, Embed_diff: 0.4971, Input_diff: 1.5542 || Time: 5.7860s
# Epoch: 11 || Acc: 0.5008, F1: 0.6670 || Edge_diff: 0.4040, Embed_diff: 0.4981, Input_diff: 1.5582 || Time: 5.8543s
# Epoch: 12 || Acc: 0.5014, F1: 0.6673 || Edge_diff: 0.4165, Embed_diff: 0.5099, Input_diff: 1.5611 || Time: 5.7427s
# Epoch: 13 || Acc: 0.5025, F1: 0.6677 || Edge_diff: 0.4224, Embed_diff: 0.5182, Input_diff: 1.5645 || Time: 5.7344s
# Epoch: 14 || Acc: 0.5033, F1: 0.6681 || Edge_diff: 0.4288, Embed_diff: 0.5159, Input_diff: 1.5680 || Time: 5.8553s
# Epoch: 15 || Acc: 0.5002, F1: 0.6663 || Edge_diff: 0.4354, Embed_diff: 0.5248, Input_diff: 1.5697 || Time: 5.7859s
# Epoch: 16 || Acc: 0.5006, F1: 0.6665 || Edge_diff: 0.4383, Embed_diff: 0.5257, Input_diff: 1.5711 || Time: 5.8348s
# Epoch: 17 || Acc: 0.5016, F1: 0.6673 || Edge_diff: 0.4357, Embed_diff: 0.5288, Input_diff: 1.5716 || Time: 5.8091s
# Epoch: 18 || Acc: 0.5008, F1: 0.6668 || Edge_diff: 0.4421, Embed_diff: 0.5233, Input_diff: 1.5737 || Time: 5.7440s
# Epoch: 19 || Acc: 0.5014, F1: 0.6672 || Edge_diff: 0.4355, Embed_diff: 0.5247, Input_diff: 1.5751 || Time: 5.8076s
# Epoch: 20 || Acc: 0.5004, F1: 0.6667 || Edge_diff: 0.4394, Embed_diff: 0.5185, Input_diff: 1.5764 || Time: 5.8398s
# Epoch: 21 || Acc: 0.5006, F1: 0.6669 || Edge_diff: 0.4367, Embed_diff: 0.5185, Input_diff: 1.5781 || Time: 5.7710s
# Epoch: 22 || Acc: 0.5008, F1: 0.6668 || Edge_diff: 0.4383, Embed_diff: 0.5080, Input_diff: 1.5795 || Time: 5.8189s
# Epoch: 23 || Acc: 0.5006, F1: 0.6668 || Edge_diff: 0.4370, Embed_diff: 0.5132, Input_diff: 1.5802 || Time: 5.8124s
# Epoch: 24 || Acc: 0.5008, F1: 0.6670 || Edge_diff: 0.4399, Embed_diff: 0.5115, Input_diff: 1.5824 || Time: 5.8314s
# Epoch: 25 || Acc: 0.5006, F1: 0.6669 || Edge_diff: 0.4333, Embed_diff: 0.5154, Input_diff: 1.5820 || Time: 5.8437s
# Epoch: 26 || Acc: 0.4998, F1: 0.6665 || Edge_diff: 0.4315, Embed_diff: 0.5106, Input_diff: 1.5839 || Time: 5.8309s
# Epoch: 27 || Acc: 0.4998, F1: 0.6665 || Edge_diff: 0.4317, Embed_diff: 0.5013, Input_diff: 1.5852 || Time: 5.8058s
# Epoch: 28 || Acc: 0.5002, F1: 0.6668 || Edge_diff: 0.4254, Embed_diff: 0.5003, Input_diff: 1.5851 || Time: 5.7828s
# Epoch: 29 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4226, Embed_diff: 0.4966, Input_diff: 1.5856 || Time: 5.8073s
# Epoch: 30 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4267, Embed_diff: 0.4980, Input_diff: 1.5877 || Time: 5.7824s
# Epoch: 31 || Acc: 0.5002, F1: 0.6668 || Edge_diff: 0.4188, Embed_diff: 0.4942, Input_diff: 1.5883 || Time: 5.7818s
# Epoch: 32 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4188, Embed_diff: 0.4944, Input_diff: 1.5886 || Time: 5.8103s
# Epoch: 33 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4137, Embed_diff: 0.4920, Input_diff: 1.5891 || Time: 5.7763s
# Epoch: 34 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4137, Embed_diff: 0.4815, Input_diff: 1.5903 || Time: 5.7790s
# Epoch: 35 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4172, Embed_diff: 0.4846, Input_diff: 1.5903 || Time: 5.7959s
# Epoch: 36 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4178, Embed_diff: 0.4861, Input_diff: 1.5913 || Time: 5.7653s
# Epoch: 37 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4161, Embed_diff: 0.4885, Input_diff: 1.5914 || Time: 5.7828s
# Epoch: 38 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4197, Embed_diff: 0.4891, Input_diff: 1.5921 || Time: 5.8590s
# Epoch: 39 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4183, Embed_diff: 0.4882, Input_diff: 1.5926 || Time: 5.7504s
# Epoch: 40 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4181, Embed_diff: 0.4881, Input_diff: 1.5938 || Time: 5.7328s
# Epoch: 41 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4224, Embed_diff: 0.4877, Input_diff: 1.5940 || Time: 5.8320s
# Epoch: 42 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4249, Embed_diff: 0.4940, Input_diff: 1.5946 || Time: 5.7494s
# Epoch: 43 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4270, Embed_diff: 0.4977, Input_diff: 1.5945 || Time: 5.8101s
# Epoch: 44 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4309, Embed_diff: 0.4996, Input_diff: 1.5954 || Time: 5.8284s
# Epoch: 45 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4311, Embed_diff: 0.5032, Input_diff: 1.5966 || Time: 5.7289s
# Epoch: 46 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4295, Embed_diff: 0.5003, Input_diff: 1.5969 || Time: 5.7475s
# Epoch: 47 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4327, Embed_diff: 0.5037, Input_diff: 1.5964 || Time: 5.7961s
# Epoch: 48 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4339, Embed_diff: 0.5032, Input_diff: 1.5968 || Time: 5.7800s
# Epoch: 49 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4356, Embed_diff: 0.5076, Input_diff: 1.5971 || Time: 5.7504s
# Epoch: 50 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4313, Embed_diff: 0.5060, Input_diff: 1.5983 || Time: 5.7984s
# Epoch: 51 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4336, Embed_diff: 0.5013, Input_diff: 1.5987 || Time: 5.7274s
# Epoch: 52 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4288, Embed_diff: 0.4999, Input_diff: 1.5982 || Time: 5.7737s
# Epoch: 53 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4242, Embed_diff: 0.4983, Input_diff: 1.5994 || Time: 5.8002s
# Epoch: 54 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4301, Embed_diff: 0.4954, Input_diff: 1.5989 || Time: 5.7942s
# Epoch: 55 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4285, Embed_diff: 0.4939, Input_diff: 1.5996 || Time: 5.7906s
# Epoch: 56 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4287, Embed_diff: 0.4954, Input_diff: 1.6012 || Time: 5.7940s
# Epoch: 57 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4262, Embed_diff: 0.4955, Input_diff: 1.6010 || Time: 5.7630s
# Epoch: 58 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4272, Embed_diff: 0.4938, Input_diff: 1.6012 || Time: 5.7750s
# Epoch: 59 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4250, Embed_diff: 0.4902, Input_diff: 1.6011 || Time: 5.7450s
# Epoch: 60 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4266, Embed_diff: 0.4936, Input_diff: 1.6008 || Time: 5.8069s
# Epoch: 61 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4267, Embed_diff: 0.4970, Input_diff: 1.6009 || Time: 5.8376s
# Epoch: 62 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4269, Embed_diff: 0.4946, Input_diff: 1.6018 || Time: 5.8947s
# Epoch: 63 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4239, Embed_diff: 0.4932, Input_diff: 1.6019 || Time: 5.7807s
# Epoch: 64 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4298, Embed_diff: 0.4974, Input_diff: 1.6017 || Time: 5.7709s
# Epoch: 65 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4340, Embed_diff: 0.4992, Input_diff: 1.6029 || Time: 5.7444s
# Epoch: 66 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4323, Embed_diff: 0.5041, Input_diff: 1.6028 || Time: 5.7056s
# Epoch: 67 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4291, Embed_diff: 0.4959, Input_diff: 1.6034 || Time: 5.7312s
# Epoch: 68 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4350, Embed_diff: 0.4961, Input_diff: 1.6033 || Time: 5.8289s
# Epoch: 69 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4334, Embed_diff: 0.5028, Input_diff: 1.6037 || Time: 5.8699s
# Epoch: 70 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4322, Embed_diff: 0.4968, Input_diff: 1.6040 || Time: 5.7837s
# Epoch: 71 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4326, Embed_diff: 0.4990, Input_diff: 1.6045 || Time: 5.8174s
# Epoch: 72 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4308, Embed_diff: 0.4987, Input_diff: 1.6037 || Time: 5.7280s
# Epoch: 73 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4305, Embed_diff: 0.5015, Input_diff: 1.6038 || Time: 5.8149s
# Epoch: 74 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4290, Embed_diff: 0.5006, Input_diff: 1.6050 || Time: 5.7813s
# Epoch: 75 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4343, Embed_diff: 0.4997, Input_diff: 1.6051 || Time: 5.8264s
# Epoch: 76 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4344, Embed_diff: 0.4968, Input_diff: 1.6057 || Time: 5.7707s
# Epoch: 77 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4326, Embed_diff: 0.4971, Input_diff: 1.6056 || Time: 5.8118s
# Epoch: 78 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4316, Embed_diff: 0.5002, Input_diff: 1.6055 || Time: 5.7608s
# Epoch: 79 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4311, Embed_diff: 0.4943, Input_diff: 1.6067 || Time: 5.8020s
# Epoch: 80 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4307, Embed_diff: 0.4955, Input_diff: 1.6055 || Time: 5.7576s
# Epoch: 81 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4312, Embed_diff: 0.4995, Input_diff: 1.6068 || Time: 5.8852s
# Epoch: 82 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4315, Embed_diff: 0.5013, Input_diff: 1.6066 || Time: 5.7367s
# Epoch: 83 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4299, Embed_diff: 0.4981, Input_diff: 1.6068 || Time: 5.7495s
# Epoch: 84 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4310, Embed_diff: 0.4963, Input_diff: 1.6065 || Time: 5.8066s
# Epoch: 85 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4314, Embed_diff: 0.5025, Input_diff: 1.6078 || Time: 5.7657s
# Epoch: 86 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4324, Embed_diff: 0.4959, Input_diff: 1.6080 || Time: 5.7475s
# Epoch: 87 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4348, Embed_diff: 0.4943, Input_diff: 1.6077 || Time: 5.8250s
# Epoch: 88 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4371, Embed_diff: 0.4987, Input_diff: 1.6088 || Time: 5.8029s
# Epoch: 89 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4387, Embed_diff: 0.5032, Input_diff: 1.6077 || Time: 5.8075s
# Epoch: 90 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4373, Embed_diff: 0.5058, Input_diff: 1.6085 || Time: 5.7595s
# Epoch: 91 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4400, Embed_diff: 0.5043, Input_diff: 1.6094 || Time: 5.8037s
# Epoch: 92 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4359, Embed_diff: 0.5050, Input_diff: 1.6082 || Time: 5.8021s
# Epoch: 93 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4335, Embed_diff: 0.5044, Input_diff: 1.6089 || Time: 5.8411s
# Epoch: 94 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4376, Embed_diff: 0.5014, Input_diff: 1.6088 || Time: 5.7751s
# Epoch: 95 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4356, Embed_diff: 0.5030, Input_diff: 1.6098 || Time: 5.7515s
# Epoch: 96 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4362, Embed_diff: 0.5028, Input_diff: 1.6096 || Time: 5.7595s
# Epoch: 97 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4365, Embed_diff: 0.5021, Input_diff: 1.6097 || Time: 5.7747s
# Epoch: 98 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4357, Embed_diff: 0.5031, Input_diff: 1.6092 || Time: 5.8296s
# Epoch: 99 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.4371, Embed_diff: 0.5028, Input_diff: 1.6107 || Time: 5.8047s
# Optimization Finished!
# Total time elapsed: 580.7103s

# %%
plt.plot(acc_values)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy Curve')
# Out:
# Text(0.5, 1.0, 'Training Accuracy Curve')

# %%
plt.plot(edge_diffs)
plt.xlabel('Epoch')
plt.ylabel('Edge-wise Distance')
plt.title('Training Edge-wise Distance Curve')
# Out:
# Text(0.5, 1.0, 'Training Edge-wise Distance Curve')

# %%
plt.plot(embed_diffs)
plt.xlabel('Epoch')
plt.ylabel('Change in Last/Curr Embedding')
plt.title('Change in Embedding Curve')
# Out:
# Text(0.5, 1.0, 'Change in Embedding Curve')

# %%
plt.plot(input_diffs)
plt.xlabel('Epoch')
plt.ylabel('Change in Input/Output')
plt.title('Change in Input/Output Curve')
# Out:
# Text(0.5, 1.0, 'Change in Input/Output Curve')

# %%
pickle.dump((acc_values, edge_diffs, embed_diffs, input_diffs), open('unsupervised_experiments_3.pkl', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)
