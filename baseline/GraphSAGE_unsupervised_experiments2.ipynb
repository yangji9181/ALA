# %%
import os
import time
import glob
import pickle
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.special import expit
from sklearn.metrics import f1_score, accuracy_score
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from baseline import *

# %%
seed = 1
device = "cuda" if torch.cuda.is_available() else "cpu"

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if device=="cuda":
    torch.cuda.manual_seed(seed)

# %% [markdown]
# ## Prepare Dataset

# %%
train_G, prediction_links = pickle.load(open('input_{}.pkl'.format(1), 'rb'))

node_features = pickle.load(open('node_features.pkl', 'rb'))
text_features = np.array(list(node_features.values()))
nnodes = text_features.shape[0]

pca = PCA(n_components=100)
pca.fit(text_features)
emb_features = pca.transform(text_features)
emb_features = torch.from_numpy(emb_features).to(device).float()
    
adj = {k:{k} for k in range(nnodes)}
for node in list(train_G.nodes()):
    adj[node] = adj[node].union(list(train_G[node]))
adj = [np.sort(list(v)) for k,v in adj.items()]

# %% [markdown]
# ## Parameters

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

nlayer = 2
dims = [100]*(nlayer+1)
dropout = 0.4

lr = 0.005
weight_decay = 0.0005

nepoch = 100

# %% [markdown]
# ## Evaluation

# %%
cos = nn.CosineSimilarity()

def lp_eval(embeds):
    lp_input = torch.stack([embeds[prediction_links[:,0]], embeds[prediction_links[:,1]]])
    similarity = cos(lp_input[0], lp_input[1]).detach().cpu().numpy()
    pred = expit(similarity)>0.5
    labels = prediction_links[:,-1]
    f1, accuracy = f1_score(labels, pred), accuracy_score(labels, pred)
    return accuracy, f1

# %%
pdist = nn.PairwiseDistance()
edges = np.array(list(train_G.edges()))

def edge_diff(embeds):
    diff = pdist(embeds[edges[:,0]], embeds[edges[:,1]])
    return torch.mean(diff).cpu().item()

# %% [markdown]
# ## Unsupervised Training, Input = initial features, Loss = - (new embedding - last embedding)

# %%
def unsup1(model, optimizer, epoch, prev_embeds):
    t = time.time()
    model.train()
    optimizer.zero_grad()
    
    embeds = model(emb_features, adj)
    loss = -torch.mean(pdist(embeds, prev_embeds))
    
    loss.backward()
    optimizer.step()
    
    accuracy, f1 = lp_eval(embeds)    
    curr_edge_diff = edge_diff(embeds)
    curr_embed_diff = -loss.item()
    curr_input_diff = torch.mean(pdist(embeds, emb_features)).cpu().item()   
    
    
    if (epoch+1)%1==0:
        print('Epoch: {} || Acc: {:.4f}, F1: {:.4f} || Edge_diff: {:.4f}, Embed_diff: {:.4f}, Input_diff: {:.4f} || Time: {:.4f}s'
              .format(epoch, accuracy, f1, curr_edge_diff, curr_embed_diff, curr_input_diff, time.time()-t))
    
    return accuracy, curr_edge_diff, curr_embed_diff, curr_input_diff, embeds

# %%
t_total = time.time()

model = GraphSAGEModel(dims=dims, dropout=dropout, nlayer=nlayer, device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

prev_embeds = emb_features
acc_values, edge_diffs, embed_diffs, input_diffs = [], [], [], []
for epoch in range(nepoch):
    acc_value, curr_edge_diff, curr_embed_diff, curr_input_diff, prev_embeds = unsup1(model, optimizer, epoch, prev_embeds.detach())
    
    acc_values.append(acc_value)
    edge_diffs.append(curr_edge_diff)
    embed_diffs.append(curr_embed_diff)
    input_diffs.append(curr_input_diff)
    
torch.save(model.state_dict(), 'Unsupervised/Version_2.pkl')  
        
print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
# Out:
# Epoch: 0 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3807, Embed_diff: 1.3241, Input_diff: 1.3241 || Time: 5.9329s
# Epoch: 1 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3810, Embed_diff: 0.6418, Input_diff: 1.3642 || Time: 5.7596s
# Epoch: 2 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3980, Embed_diff: 0.6990, Input_diff: 1.3928 || Time: 5.8417s
# Epoch: 3 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3535, Embed_diff: 0.6869, Input_diff: 1.4030 || Time: 5.7690s
# Epoch: 4 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.2969, Embed_diff: 0.5859, Input_diff: 1.3989 || Time: 5.7352s
# Epoch: 5 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.2517, Embed_diff: 0.4856, Input_diff: 1.3917 || Time: 5.7507s
# Epoch: 6 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.2235, Embed_diff: 0.4276, Input_diff: 1.3840 || Time: 5.7411s
# Epoch: 7 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.1975, Embed_diff: 0.3840, Input_diff: 1.3762 || Time: 5.7078s
# Epoch: 8 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.1765, Embed_diff: 0.3413, Input_diff: 1.3682 || Time: 5.8315s
# Epoch: 9 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.1598, Embed_diff: 0.3077, Input_diff: 1.3602 || Time: 5.7521s
# Epoch: 10 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.1471, Embed_diff: 0.2833, Input_diff: 1.3537 || Time: 5.7755s
# Epoch: 11 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.1339, Embed_diff: 0.2623, Input_diff: 1.3478 || Time: 5.7381s
# Epoch: 12 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.1242, Embed_diff: 0.2452, Input_diff: 1.3426 || Time: 5.7420s
# Epoch: 13 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.1164, Embed_diff: 0.2278, Input_diff: 1.3382 || Time: 5.7416s
# Epoch: 14 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.1077, Embed_diff: 0.2127, Input_diff: 1.3354 || Time: 5.7921s
# Epoch: 15 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.1009, Embed_diff: 0.1993, Input_diff: 1.3330 || Time: 5.6993s
# Epoch: 16 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0955, Embed_diff: 0.1864, Input_diff: 1.3314 || Time: 5.7383s
# Epoch: 17 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0893, Embed_diff: 0.1762, Input_diff: 1.3306 || Time: 5.7439s
# Epoch: 18 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0844, Embed_diff: 0.1648, Input_diff: 1.3292 || Time: 5.7298s
# Epoch: 19 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0798, Embed_diff: 0.1529, Input_diff: 1.3282 || Time: 5.7682s
# Epoch: 20 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0759, Embed_diff: 0.1461, Input_diff: 1.3276 || Time: 5.8108s
# Epoch: 21 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0732, Embed_diff: 0.1388, Input_diff: 1.3273 || Time: 5.7751s
# Epoch: 22 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0702, Embed_diff: 0.1340, Input_diff: 1.3267 || Time: 5.7702s
# Epoch: 23 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0686, Embed_diff: 0.1274, Input_diff: 1.3262 || Time: 5.8112s
# Epoch: 24 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0675, Embed_diff: 0.1267, Input_diff: 1.3262 || Time: 5.7355s
# Epoch: 25 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0669, Embed_diff: 0.1256, Input_diff: 1.3260 || Time: 5.7621s
# Epoch: 26 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0657, Embed_diff: 0.1229, Input_diff: 1.3260 || Time: 5.8588s
# Epoch: 27 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0650, Embed_diff: 0.1206, Input_diff: 1.3257 || Time: 5.7207s
# Epoch: 28 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0637, Embed_diff: 0.1181, Input_diff: 1.3253 || Time: 5.7515s
# Epoch: 29 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0616, Embed_diff: 0.1139, Input_diff: 1.3250 || Time: 5.7665s
# Epoch: 30 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0605, Embed_diff: 0.1121, Input_diff: 1.3248 || Time: 5.7947s
# Epoch: 31 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0597, Embed_diff: 0.1107, Input_diff: 1.3247 || Time: 5.7366s
# Epoch: 32 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0588, Embed_diff: 0.1090, Input_diff: 1.3245 || Time: 5.8152s
# Epoch: 33 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0577, Embed_diff: 0.1054, Input_diff: 1.3244 || Time: 5.7625s
# Epoch: 34 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0577, Embed_diff: 0.1076, Input_diff: 1.3241 || Time: 5.7298s
# Epoch: 35 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0572, Embed_diff: 0.1043, Input_diff: 1.3239 || Time: 5.7347s
# Epoch: 36 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0573, Embed_diff: 0.1044, Input_diff: 1.3239 || Time: 5.7691s
# Epoch: 37 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0566, Embed_diff: 0.1018, Input_diff: 1.3239 || Time: 5.7151s
# Epoch: 38 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0567, Embed_diff: 0.1051, Input_diff: 1.3239 || Time: 5.7386s
# Epoch: 39 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0564, Embed_diff: 0.1026, Input_diff: 1.3235 || Time: 5.7611s
# Epoch: 40 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0562, Embed_diff: 0.1013, Input_diff: 1.3236 || Time: 5.7661s
# Epoch: 41 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0559, Embed_diff: 0.1021, Input_diff: 1.3235 || Time: 5.7232s
# Epoch: 42 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0554, Embed_diff: 0.0992, Input_diff: 1.3234 || Time: 5.7452s
# Epoch: 43 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0542, Embed_diff: 0.0995, Input_diff: 1.3233 || Time: 5.7700s
# Epoch: 44 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0534, Embed_diff: 0.0963, Input_diff: 1.3230 || Time: 5.7698s
# Epoch: 45 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0523, Embed_diff: 0.0932, Input_diff: 1.3233 || Time: 5.7508s
# Epoch: 46 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0513, Embed_diff: 0.0898, Input_diff: 1.3229 || Time: 5.7510s
# Epoch: 47 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0492, Embed_diff: 0.0881, Input_diff: 1.3227 || Time: 5.7170s
# Epoch: 48 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0468, Embed_diff: 0.0846, Input_diff: 1.3227 || Time: 5.7438s
# Epoch: 49 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0446, Embed_diff: 0.0810, Input_diff: 1.3228 || Time: 5.7700s
# Epoch: 50 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0427, Embed_diff: 0.0764, Input_diff: 1.3226 || Time: 5.7674s
# Epoch: 51 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0395, Embed_diff: 0.0731, Input_diff: 1.3224 || Time: 5.7332s
# Epoch: 52 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0373, Embed_diff: 0.0683, Input_diff: 1.3223 || Time: 5.6978s
# Epoch: 53 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0357, Embed_diff: 0.0648, Input_diff: 1.3222 || Time: 5.7299s
# Epoch: 54 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0345, Embed_diff: 0.0634, Input_diff: 1.3221 || Time: 5.7537s
# Epoch: 55 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0333, Embed_diff: 0.0610, Input_diff: 1.3223 || Time: 5.7262s
# Epoch: 56 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0334, Embed_diff: 0.0611, Input_diff: 1.3219 || Time: 5.8093s
# Epoch: 57 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0335, Embed_diff: 0.0606, Input_diff: 1.3220 || Time: 5.7492s
# Epoch: 58 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0339, Embed_diff: 0.0612, Input_diff: 1.3221 || Time: 5.7886s
# Epoch: 59 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0344, Embed_diff: 0.0620, Input_diff: 1.3220 || Time: 5.6983s
# Epoch: 60 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0345, Embed_diff: 0.0644, Input_diff: 1.3219 || Time: 5.7203s
# Epoch: 61 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0361, Embed_diff: 0.0652, Input_diff: 1.3220 || Time: 5.7452s
# Epoch: 62 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0368, Embed_diff: 0.0669, Input_diff: 1.3219 || Time: 5.8585s
# Epoch: 63 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0372, Embed_diff: 0.0671, Input_diff: 1.3219 || Time: 5.7563s
# Epoch: 64 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0395, Embed_diff: 0.0690, Input_diff: 1.3219 || Time: 5.7315s
# Epoch: 65 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0401, Embed_diff: 0.0713, Input_diff: 1.3220 || Time: 5.7654s
# Epoch: 66 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0410, Embed_diff: 0.0727, Input_diff: 1.3222 || Time: 5.6964s
# Epoch: 67 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0425, Embed_diff: 0.0736, Input_diff: 1.3222 || Time: 5.7890s
# Epoch: 68 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0430, Embed_diff: 0.0751, Input_diff: 1.3220 || Time: 5.7521s
# Epoch: 69 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0442, Embed_diff: 0.0778, Input_diff: 1.3221 || Time: 5.7151s
# Epoch: 70 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0451, Embed_diff: 0.0780, Input_diff: 1.3221 || Time: 5.7247s
# Epoch: 71 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0461, Embed_diff: 0.0797, Input_diff: 1.3222 || Time: 5.7140s
# Epoch: 72 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0465, Embed_diff: 0.0779, Input_diff: 1.3221 || Time: 5.7172s
# Epoch: 73 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0472, Embed_diff: 0.0785, Input_diff: 1.3219 || Time: 5.7523s
# Epoch: 74 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0480, Embed_diff: 0.0793, Input_diff: 1.3215 || Time: 5.7607s
# Epoch: 75 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0482, Embed_diff: 0.0804, Input_diff: 1.3211 || Time: 5.8395s
# Epoch: 76 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0483, Embed_diff: 0.0811, Input_diff: 1.3208 || Time: 5.7025s
# Epoch: 77 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0494, Embed_diff: 0.0838, Input_diff: 1.3204 || Time: 5.7871s
# Epoch: 78 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0498, Embed_diff: 0.0829, Input_diff: 1.3203 || Time: 5.7380s
# Epoch: 79 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0500, Embed_diff: 0.0830, Input_diff: 1.3202 || Time: 5.7021s
# Epoch: 80 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0501, Embed_diff: 0.0835, Input_diff: 1.3200 || Time: 5.7233s
# Epoch: 81 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0507, Embed_diff: 0.0869, Input_diff: 1.3201 || Time: 5.7933s
# Epoch: 82 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0509, Embed_diff: 0.0859, Input_diff: 1.3201 || Time: 5.7974s
# Epoch: 83 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0506, Embed_diff: 0.0865, Input_diff: 1.3199 || Time: 5.8279s
# Epoch: 84 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0514, Embed_diff: 0.0877, Input_diff: 1.3199 || Time: 5.7830s
# Epoch: 85 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0517, Embed_diff: 0.0884, Input_diff: 1.3200 || Time: 5.7807s
# Epoch: 86 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0515, Embed_diff: 0.0894, Input_diff: 1.3200 || Time: 5.7589s
# Epoch: 87 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0521, Embed_diff: 0.0896, Input_diff: 1.3198 || Time: 5.8562s
# Epoch: 88 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0523, Embed_diff: 0.0906, Input_diff: 1.3198 || Time: 5.7329s
# Epoch: 89 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0524, Embed_diff: 0.0907, Input_diff: 1.3198 || Time: 5.7244s
# Epoch: 90 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0523, Embed_diff: 0.0927, Input_diff: 1.3197 || Time: 5.6983s
# Epoch: 91 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0526, Embed_diff: 0.0923, Input_diff: 1.3199 || Time: 5.7087s
# Epoch: 92 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0523, Embed_diff: 0.0932, Input_diff: 1.3197 || Time: 5.7477s
# Epoch: 93 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0527, Embed_diff: 0.0918, Input_diff: 1.3198 || Time: 5.7683s
# Epoch: 94 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0528, Embed_diff: 0.0936, Input_diff: 1.3198 || Time: 5.7712s
# Epoch: 95 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0527, Embed_diff: 0.0932, Input_diff: 1.3198 || Time: 5.7975s
# Epoch: 96 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0528, Embed_diff: 0.0945, Input_diff: 1.3197 || Time: 5.7111s
# Epoch: 97 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0532, Embed_diff: 0.0936, Input_diff: 1.3197 || Time: 5.8012s
# Epoch: 98 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0530, Embed_diff: 0.0962, Input_diff: 1.3196 || Time: 5.7169s
# Epoch: 99 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.0533, Embed_diff: 0.0937, Input_diff: 1.3196 || Time: 5.7930s
# Optimization Finished!
# Total time elapsed: 577.3945s

# %%
plt.plot(acc_values)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy Curve')
# Out:
# Text(0.5, 1.0, 'Training Accuracy Curve')

# %%
plt.plot(edge_diffs)
plt.xlabel('Epoch')
plt.ylabel('Edge-wise Distance')
plt.title('Training Edge-wise Distance Curve')
# Out:
# Text(0.5, 1.0, 'Training Edge-wise Distance Curve')

# %%
plt.plot(embed_diffs)
plt.xlabel('Epoch')
plt.ylabel('Change in Last/Curr Embedding')
plt.title('Change in Embedding Curve')
# Out:
# Text(0.5, 1.0, 'Change in Embedding Curve')

# %%
plt.plot(input_diffs)
plt.xlabel('Epoch')
plt.ylabel('Change in Input/Output')
plt.title('Change in Input/Output Curve')
# Out:
# Text(0.5, 1.0, 'Change in Input/Output Curve')

# %%
pickle.dump((acc_values, edge_diffs, embed_diffs, input_diffs), open('unsupervised_experiments_2.pkl', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)
