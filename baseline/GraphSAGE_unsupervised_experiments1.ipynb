# %%
import os
import time
import glob
import pickle
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.special import expit
from sklearn.metrics import f1_score, accuracy_score
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from baseline import *

# %%
seed = 1
device = "cuda" if torch.cuda.is_available() else "cpu"

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if device=="cuda":
    torch.cuda.manual_seed(seed)

# %% [markdown]
# ## Prepare Dataset

# %%
train_G, prediction_links = pickle.load(open('input_{}.pkl'.format(1), 'rb'))

node_features = pickle.load(open('node_features.pkl', 'rb'))
text_features = np.array(list(node_features.values()))
nnodes = text_features.shape[0]

pca = PCA(n_components=100)
pca.fit(text_features)
emb_features = pca.transform(text_features)
emb_features = torch.from_numpy(emb_features).to(device).float()
    
adj = {k:{k} for k in range(nnodes)}
for node in list(train_G.nodes()):
    adj[node] = adj[node].union(list(train_G[node]))
adj = [np.sort(list(v)) for k,v in adj.items()]

# %% [markdown]
# ## Parameters

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

nlayer = 2
dims = [100]*(nlayer+1)
dropout = 0.4

lr = 0.005
weight_decay = 0.0005

nepoch = 100

# %% [markdown]
# ## Evaluation

# %%
cos = nn.CosineSimilarity()

def lp_eval(embeds):
    lp_input = torch.stack([embeds[prediction_links[:,0]], embeds[prediction_links[:,1]]])
    similarity = cos(lp_input[0], lp_input[1]).detach().cpu().numpy()
    pred = expit(similarity)>0.5
    labels = prediction_links[:,-1]
    f1, accuracy = f1_score(labels, pred), accuracy_score(labels, pred)
    return accuracy, f1

# %%
pdist = nn.PairwiseDistance()
edges = np.array(list(train_G.edges()))

def edge_diff(embeds):
    diff = pdist(embeds[edges[:,0]], embeds[edges[:,1]])
    return torch.mean(diff).cpu().item()

# %% [markdown]
# ## Unsupervised Training, Input = last embedding, Loss = - (new embedding - last embedding)

# %%
def unsup1(model, optimizer, epoch, prev_embeds):
    t = time.time()
    model.train()
    optimizer.zero_grad()
    
    embeds = model(prev_embeds, adj)
    loss = -torch.mean(pdist(embeds, prev_embeds))
    
    loss.backward()
    optimizer.step()
    
    accuracy, f1 = lp_eval(embeds)    
    curr_edge_diff = edge_diff(embeds)
    curr_embed_diff = -loss.item()
    curr_input_diff = torch.mean(pdist(embeds, emb_features)).cpu().item()   
    
    
    if (epoch+1)%1==0:
        print('Epoch: {} || Acc: {:.4f}, F1: {:.4f} || Edge_diff: {:.4f}, Embed_diff: {:.4f}, Input_diff: {:.4f} || Time: {:.4f}s'
              .format(epoch, accuracy, f1, curr_edge_diff, curr_embed_diff, curr_input_diff, time.time()-t))
    
    return accuracy, curr_edge_diff, curr_embed_diff, curr_input_diff, embeds

# %%
t_total = time.time()

model = GraphSAGEModel(dims=dims, dropout=dropout, nlayer=nlayer, device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

prev_embeds = emb_features
acc_values, edge_diffs, embed_diffs, input_diffs = [], [], [], []
for epoch in range(nepoch):
    acc_value, curr_edge_diff, curr_embed_diff, curr_input_diff, prev_embeds = unsup1(model, optimizer, epoch, prev_embeds.detach())
    
    acc_values.append(acc_value)
    edge_diffs.append(curr_edge_diff)
    embed_diffs.append(curr_embed_diff)
    input_diffs.append(curr_input_diff)
    
torch.save(model.state_dict(), 'Unsupervised/Version_1.pkl')  
        
print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
# Out:
# Epoch: 0 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3807, Embed_diff: 1.3241, Input_diff: 1.3241 || Time: 5.9360s
# Epoch: 1 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.2802, Embed_diff: 1.0097, Input_diff: 1.3157 || Time: 5.7543s
# Epoch: 2 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.2876, Embed_diff: 0.9364, Input_diff: 1.3231 || Time: 5.8384s
# Epoch: 3 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3552, Embed_diff: 1.1246, Input_diff: 1.3188 || Time: 5.7691s
# Epoch: 4 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3496, Embed_diff: 1.1459, Input_diff: 1.3245 || Time: 5.9043s
# Epoch: 5 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3048, Embed_diff: 1.1978, Input_diff: 1.3186 || Time: 5.8533s
# Epoch: 6 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.3220, Embed_diff: 1.2057, Input_diff: 1.3199 || Time: 5.7821s
# Epoch: 7 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.2984, Embed_diff: 1.2485, Input_diff: 1.3196 || Time: 5.8772s
# Epoch: 8 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.2722, Embed_diff: 1.3039, Input_diff: 1.3218 || Time: 5.8625s
# Epoch: 9 || Acc: 0.5000, F1: 0.6667 || Edge_diff: 0.2614, Embed_diff: 1.3516, Input_diff: 1.3182 || Time: 5.8677s
# Epoch: 10 || Acc: 0.5043, F1: 0.6686 || Edge_diff: 0.2170, Embed_diff: 1.3790, Input_diff: 1.3209 || Time: 5.8160s
# Epoch: 11 || Acc: 0.5161, F1: 0.6738 || Edge_diff: 0.2216, Embed_diff: 1.3960, Input_diff: 1.3177 || Time: 5.8151s
# Epoch: 12 || Acc: 0.5237, F1: 0.6770 || Edge_diff: 0.1957, Embed_diff: 1.4034, Input_diff: 1.3214 || Time: 5.8913s
# Epoch: 13 || Acc: 0.5394, F1: 0.6836 || Edge_diff: 0.1962, Embed_diff: 1.4060, Input_diff: 1.3168 || Time: 5.8251s
# Epoch: 14 || Acc: 0.5652, F1: 0.6961 || Edge_diff: 0.1885, Embed_diff: 1.4089, Input_diff: 1.3225 || Time: 5.9655s
# Epoch: 15 || Acc: 0.5981, F1: 0.7110 || Edge_diff: 0.1798, Embed_diff: 1.4096, Input_diff: 1.3168 || Time: 5.8712s
# Epoch: 16 || Acc: 0.6027, F1: 0.7134 || Edge_diff: 0.1799, Embed_diff: 1.4111, Input_diff: 1.3221 || Time: 5.8607s
# Epoch: 17 || Acc: 0.6138, F1: 0.7181 || Edge_diff: 0.1745, Embed_diff: 1.4115, Input_diff: 1.3159 || Time: 5.8097s
# Epoch: 18 || Acc: 0.6148, F1: 0.7184 || Edge_diff: 0.1750, Embed_diff: 1.4120, Input_diff: 1.3210 || Time: 5.8277s
# Epoch: 19 || Acc: 0.6219, F1: 0.7213 || Edge_diff: 0.1723, Embed_diff: 1.4125, Input_diff: 1.3169 || Time: 5.8644s
# Epoch: 20 || Acc: 0.6198, F1: 0.7208 || Edge_diff: 0.1750, Embed_diff: 1.4129, Input_diff: 1.3220 || Time: 5.8633s
# Epoch: 21 || Acc: 0.6243, F1: 0.7224 || Edge_diff: 0.1699, Embed_diff: 1.4129, Input_diff: 1.3167 || Time: 5.8112s
# Epoch: 22 || Acc: 0.6223, F1: 0.7214 || Edge_diff: 0.1767, Embed_diff: 1.4130, Input_diff: 1.3216 || Time: 5.8127s
# Epoch: 23 || Acc: 0.6250, F1: 0.7220 || Edge_diff: 0.1704, Embed_diff: 1.4132, Input_diff: 1.3166 || Time: 5.8705s
# Epoch: 24 || Acc: 0.6254, F1: 0.7226 || Edge_diff: 0.1777, Embed_diff: 1.4135, Input_diff: 1.3208 || Time: 5.8317s
# Epoch: 65 || Acc: 0.6272, F1: 0.7226 || Edge_diff: 0.1748, Embed_diff: 1.4117, Input_diff: 1.3155 || Time: 5.7983s
# Epoch: 66 || Acc: 0.6274, F1: 0.7228 || Edge_diff: 0.1638, Embed_diff: 1.4124, Input_diff: 1.3210 || Time: 5.8099s
# Epoch: 67 || Acc: 0.6274, F1: 0.7222 || Edge_diff: 0.1731, Embed_diff: 1.4121, Input_diff: 1.3153 || Time: 5.8161s
# Epoch: 68 || Acc: 0.6270, F1: 0.7224 || Edge_diff: 0.1681, Embed_diff: 1.4115, Input_diff: 1.3202 || Time: 5.8330s
# Epoch: 69 || Acc: 0.6280, F1: 0.7232 || Edge_diff: 0.1736, Embed_diff: 1.4116, Input_diff: 1.3154 || Time: 5.9333s
# Epoch: 70 || Acc: 0.6264, F1: 0.7221 || Edge_diff: 0.1642, Embed_diff: 1.4118, Input_diff: 1.3204 || Time: 5.8167s
# Epoch: 71 || Acc: 0.6260, F1: 0.7214 || Edge_diff: 0.1746, Embed_diff: 1.4113, Input_diff: 1.3155 || Time: 5.8112s
# Epoch: 72 || Acc: 0.6272, F1: 0.7225 || Edge_diff: 0.1655, Embed_diff: 1.4113, Input_diff: 1.3208 || Time: 5.7823s
# Epoch: 73 || Acc: 0.6268, F1: 0.7225 || Edge_diff: 0.1723, Embed_diff: 1.4117, Input_diff: 1.3151 || Time: 5.7975s
# Epoch: 74 || Acc: 0.6283, F1: 0.7236 || Edge_diff: 0.1622, Embed_diff: 1.4119, Input_diff: 1.3212 || Time: 5.7808s
# Epoch: 75 || Acc: 0.6272, F1: 0.7226 || Edge_diff: 0.1743, Embed_diff: 1.4122, Input_diff: 1.3157 || Time: 5.9344s
# Epoch: 76 || Acc: 0.6272, F1: 0.7228 || Edge_diff: 0.1626, Embed_diff: 1.4121, Input_diff: 1.3206 || Time: 5.8620s
# Epoch: 77 || Acc: 0.6272, F1: 0.7222 || Edge_diff: 0.1709, Embed_diff: 1.4121, Input_diff: 1.3159 || Time: 5.8463s
# Epoch: 78 || Acc: 0.6274, F1: 0.7227 || Edge_diff: 0.1636, Embed_diff: 1.4118, Input_diff: 1.3207 || Time: 5.8508s
# Epoch: 79 || Acc: 0.6282, F1: 0.7231 || Edge_diff: 0.1751, Embed_diff: 1.4109, Input_diff: 1.3148 || Time: 5.8161s
# Epoch: 80 || Acc: 0.6262, F1: 0.7219 || Edge_diff: 0.1625, Embed_diff: 1.4111, Input_diff: 1.3201 || Time: 5.8703s
# Epoch: 81 || Acc: 0.6258, F1: 0.7219 || Edge_diff: 0.1744, Embed_diff: 1.4121, Input_diff: 1.3157 || Time: 5.8503s
# Epoch: 82 || Acc: 0.6262, F1: 0.7221 || Edge_diff: 0.1628, Embed_diff: 1.4125, Input_diff: 1.3208 || Time: 5.8556s
# Epoch: 83 || Acc: 0.6266, F1: 0.7221 || Edge_diff: 0.1754, Embed_diff: 1.4120, Input_diff: 1.3158 || Time: 5.8314s
# Epoch: 84 || Acc: 0.6268, F1: 0.7221 || Edge_diff: 0.1640, Embed_diff: 1.4115, Input_diff: 1.3206 || Time: 5.8696s
# Epoch: 85 || Acc: 0.6274, F1: 0.7226 || Edge_diff: 0.1722, Embed_diff: 1.4112, Input_diff: 1.3153 || Time: 5.8505s
# Epoch: 86 || Acc: 0.6254, F1: 0.7214 || Edge_diff: 0.1630, Embed_diff: 1.4118, Input_diff: 1.3205 || Time: 5.8579s
# Epoch: 87 || Acc: 0.6258, F1: 0.7216 || Edge_diff: 0.1715, Embed_diff: 1.4119, Input_diff: 1.3158 || Time: 5.8827s
# Epoch: 88 || Acc: 0.6256, F1: 0.7214 || Edge_diff: 0.1615, Embed_diff: 1.4117, Input_diff: 1.3207 || Time: 5.8659s
# Epoch: 89 || Acc: 0.6264, F1: 0.7220 || Edge_diff: 0.1733, Embed_diff: 1.4119, Input_diff: 1.3158 || Time: 5.9006s
# Epoch: 90 || Acc: 0.6268, F1: 0.7225 || Edge_diff: 0.1600, Embed_diff: 1.4123, Input_diff: 1.3215 || Time: 5.8584s
# Epoch: 91 || Acc: 0.6258, F1: 0.7218 || Edge_diff: 0.1700, Embed_diff: 1.4123, Input_diff: 1.3160 || Time: 5.8528s
# Epoch: 92 || Acc: 0.6258, F1: 0.7219 || Edge_diff: 0.1578, Embed_diff: 1.4122, Input_diff: 1.3214 || Time: 5.8711s
# Epoch: 93 || Acc: 0.6262, F1: 0.7220 || Edge_diff: 0.1705, Embed_diff: 1.4119, Input_diff: 1.3162 || Time: 5.8618s
# Epoch: 94 || Acc: 0.6264, F1: 0.7222 || Edge_diff: 0.1581, Embed_diff: 1.4116, Input_diff: 1.3207 || Time: 5.8194s
# Epoch: 95 || Acc: 0.6260, F1: 0.7220 || Edge_diff: 0.1723, Embed_diff: 1.4116, Input_diff: 1.3153 || Time: 5.8030s
# Epoch: 96 || Acc: 0.6270, F1: 0.7227 || Edge_diff: 0.1578, Embed_diff: 1.4123, Input_diff: 1.3210 || Time: 5.8275s
# Epoch: 97 || Acc: 0.6270, F1: 0.7224 || Edge_diff: 0.1713, Embed_diff: 1.4125, Input_diff: 1.3155 || Time: 5.8642s
# Epoch: 98 || Acc: 0.6266, F1: 0.7221 || Edge_diff: 0.1604, Embed_diff: 1.4120, Input_diff: 1.3212 || Time: 5.8184s
# Epoch: 99 || Acc: 0.6283, F1: 0.7236 || Edge_diff: 0.1720, Embed_diff: 1.4120, Input_diff: 1.3150 || Time: 5.9264s
# Optimization Finished!
# Total time elapsed: 586.2468s

# %%
plt.plot(acc_values)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy Curve')
# Out:
# Text(0.5, 1.0, 'Training Accuracy Curve')

# %%
plt.plot(edge_diffs)
plt.xlabel('Epoch')
plt.ylabel('Edge-wise Distance')
plt.title('Training Edge-wise Distance Curve')
# Out:
# Text(0.5, 1.0, 'Training Edge-wise Distance Curve')

# %%
plt.plot(embed_diffs)
plt.xlabel('Epoch')
plt.ylabel('Change in Last/Curr Embedding')
plt.title('Change in Embedding Curve')
# Out:
# Text(0.5, 1.0, 'Change in Embedding Curve')

# %%
plt.plot(input_diffs)
plt.xlabel('Epoch')
plt.ylabel('Change in Input/Output')
plt.title('Change in Input/Output Curve')
# Out:
# Text(0.5, 1.0, 'Change in Input/Output Curve')

# %%
pickle.dump((acc_values, edge_diffs, embed_diffs, input_diffs), open('unsupervised_experiments_1.pkl', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)
