# %%
import os
import time
import glob
import pickle
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from collections import defaultdict
from scipy.special import expit
from sklearn.metrics import f1_score, accuracy_score
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from baseline import *

# %%
seed = 1
device = "cuda" if torch.cuda.is_available() else "cpu"

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if device=="cuda":
    torch.cuda.manual_seed(seed)

# %% [markdown]
# ## Prepare Dataset

# %%
lp_train = pickle.load(open('data/cora/lp_train.pkl', 'rb'))
lp_test = pickle.load(open('data/cora/lp_test.pkl', 'rb'))

node_features = pickle.load(open('data/cora/node_features.pkl', 'rb'))
text_features = node_features.toarray()
nnodes = text_features.shape[0]

pca = PCA(n_components=100)
pca.fit(text_features)
emb_features = pca.transform(text_features)
emb_features = torch.from_numpy(emb_features).to(device).float()
    
adjs = defaultdict(set)
for node in list(lp_train.nodes()):
    adjs[node] = adjs[node].union(lp_train[node])
adjs = [np.sort(list(v)) for k,v in adjs.items()]

# %% [markdown]
# ## Parameters

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

nlayer = 1
dims = [100]*(nlayer+1)
dropout = 0.4

lr = 0.005
weight_decay = 0.0005

patience = 50
nepoch = 10000

# %% [markdown]
# ## Link Prediction Supervised Training

# %%
# posi, nega = [], []
# for node in range(nnodes):
#     neighbors = list(lp_train[node])
#     nega_neighbors = random.sample(list(set(range(nnodes)).difference(set(neighbors))), 5)
#     nega.append(np.stack(([node]*len(nega_neighbors), nega_neighbors), axis=-1))
#     posi.append(np.stack(([node]*len(neighbors), neighbors), axis=-1))
# posi = np.concatenate(posi, axis=0)
# nega = np.concatenate(nega, axis=0)

# X_train = np.concatenate([posi,nega], axis=0)
# y_train = torch.from_numpy(np.concatenate([[1]*len(posi), [0]*len(nega)])).float().to(device)
# X_test = lp_test[:,:-1]
# y_test = torch.from_numpy(lp_test[:,-1]).float().to(device)

# %%
X_train, y_train, X_test, y_test = pickle.load(open('simulation/train_test.pkl', 'rb'))
y_train = torch.from_numpy(y_train).float().to(device)
y_test = torch.from_numpy(y_test).float().to(device)

# %% [markdown]
# ## Train & Test

# %%
def evaluate(cos_sim, labels):
    pred = expit(cos_sim)>0.5
    f1, accuracy = f1_score(labels, pred), accuracy_score(labels, pred)
    return accuracy, f1

# %%
pdist = nn.PairwiseDistance()
edges = np.array(list(lp_train.edges()))

def edge_diff(embeds):
    diff = pdist(embeds[edges[:,0]], embeds[edges[:,1]])
    return torch.mean(diff).cpu().item()

def embed_diff(embeds, prev_embeds):
    diff = pdist(embeds, prev_embeds)
    return torch.mean(diff).cpu().item()

# %%
cos = nn.CosineSimilarity()

def sup_train(model, optimizer, epoch, prev_embeds):
    t = time.time()
    model.train()
    optimizer.zero_grad()
    
    real_adjs = []
    for node, neighbors in enumerate(adjs):
        if len(neighbors)>3:
            real_neighbors = random.sample(neighbors.tolist(), 3)
        else:
            real_neighbors = list(neighbors)
        real_neighbors.append(node)
        real_adjs.append(real_neighbors)
    
    embeds = model(emb_features, real_adjs)
    lp_input = torch.stack([embeds[X_train[:,0]], embeds[X_train[:,1]]])
    similarity = cos(lp_input[0], lp_input[1])
    loss = F.binary_cross_entropy_with_logits(similarity, y_train)
    
    accuracy, f1 = evaluate(similarity.detach().cpu().numpy(), y_train.cpu().numpy())
    curr_edge_diff = edge_diff(embeds)
    curr_embed_diff = embed_diff(embeds, prev_embeds)
    curr_input_diff = embed_diff(embeds, emb_features)
    
    loss.backward()
    optimizer.step()
    
    if (epoch+1)%1==0:
        print('Epoch: {} || Loss: {:.4f}, Acc: {:.4f}, F1: {:.4f} || Edge_diff: {:.4f}, Embed_diff: {:.4f}, Input_diff: {:.4f} || Time: {:.4f}s'
              .format(epoch, loss.item(), accuracy, f1, curr_edge_diff, curr_embed_diff, curr_input_diff, time.time()-t))
    
    return loss.item(), curr_edge_diff, curr_embed_diff, curr_input_diff, embeds

# %%
def sup_test(model):
    model.eval()
    
    real_adjs = []
    for node, neighbors in enumerate(adjs):
        if len(neighbors)>3:
            real_neighbors = random.sample(neighbors.tolist(), 3)
        else:
            real_neighbors = list(neighbors)
        real_neighbors.append(node)
        real_adjs.append(real_neighbors)
    
    embeds = model(emb_features, real_adjs)
    lp_input = torch.stack([embeds[X_test[:,0]], embeds[X_test[:,1]]])
    similarity = cos(lp_input[0], lp_input[1])
    loss = F.binary_cross_entropy_with_logits(similarity, y_test)
    
    accuracy, f1 = evaluate(similarity.detach().cpu().numpy(), y_test.cpu().numpy())
    
    print('Loss: {:.4f}, Acc: {:.4f}, F1: {:.4f}'.format(loss.item(), accuracy, f1))

# %%
t_total = time.time()

model = GraphSAGEModel(dims=dims, dropout=dropout, nlayer=nlayer, device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

prev_embeds = emb_features
loss_values, edge_diffs, embed_diffs, input_diffs = [], [], [], []
bad_counter, best, best_epoch = 0, nepoch+1, 0
for epoch in range(nepoch):
    loss_value, curr_edge_diff, curr_embed_diff, curr_input_diff, prev_embeds = sup_train(model, optimizer, epoch, prev_embeds)
    
    loss_values.append(loss_value)
    edge_diffs.append(curr_edge_diff)
    embed_diffs.append(curr_embed_diff)
    input_diffs.append(curr_input_diff)
    
    torch.save(model.state_dict(), 'model/Supervised/{}.pkl'.format(epoch))
    
    if loss_values[-1] < best:
        best, best_epoch, bad_counter = loss_values[-1], epoch, 0
    else:
        bad_counter += 1
                
    if bad_counter == patience:
        break
        
    files = glob.glob('model/Supervised/*.pkl')
    for file in files:
        epoch_nb = int(file.split('.')[0].split('/')[-1])
        if epoch_nb < best_epoch:
            os.remove(file) 
    
files = glob.glob('model/Supervised/*.pkl')
for file in files:
    epoch_nb = int(file.split('.')[0].split('/')[-1])
    if epoch_nb > best_epoch:
        os.remove(file) 
        
print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))

print('Loading {}th epoch'.format(best_epoch))
model.load_state_dict(torch.load('model/Supervised/{}.pkl'.format(best_epoch)))

sup_test(model)
# Out:
# Epoch: 0 || Loss: 0.6961, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.7775, Embed_diff: 1.0151, Input_diff: 1.0151 || Time: 0.6478s
# Epoch: 1 || Loss: 0.6932, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.7689, Embed_diff: 0.7508, Input_diff: 1.0148 || Time: 0.4223s
# Epoch: 2 || Loss: 0.6905, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.7575, Embed_diff: 0.7447, Input_diff: 1.0148 || Time: 0.4138s
# Epoch: 3 || Loss: 0.6863, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.7452, Embed_diff: 0.7258, Input_diff: 1.0145 || Time: 0.4093s
# Epoch: 4 || Loss: 0.6839, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.7407, Embed_diff: 0.7186, Input_diff: 1.0146 || Time: 0.3870s
# Epoch: 5 || Loss: 0.6805, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.7290, Embed_diff: 0.7184, Input_diff: 1.0147 || Time: 0.4234s
# Epoch: 6 || Loss: 0.6772, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.7149, Embed_diff: 0.6899, Input_diff: 1.0142 || Time: 0.3359s
# Epoch: 7 || Loss: 0.6759, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.7144, Embed_diff: 0.6895, Input_diff: 1.0144 || Time: 0.4267s
# Epoch: 8 || Loss: 0.6717, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.6947, Embed_diff: 0.6804, Input_diff: 1.0144 || Time: 0.6572s
# Epoch: 9 || Loss: 0.6698, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.6925, Embed_diff: 0.6706, Input_diff: 1.0143 || Time: 0.7167s
# Epoch: 10 || Loss: 0.6664, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.6735, Embed_diff: 0.6636, Input_diff: 1.0142 || Time: 0.6193s
# Epoch: 11 || Loss: 0.6656, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.6824, Embed_diff: 0.6438, Input_diff: 1.0141 || Time: 0.7328s
# Epoch: 12 || Loss: 0.6631, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.6686, Embed_diff: 0.6435, Input_diff: 1.0144 || Time: 0.5562s
# Epoch: 13 || Loss: 0.6613, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.6597, Embed_diff: 0.6361, Input_diff: 1.0140 || Time: 0.6890s
# Epoch: 14 || Loss: 0.6572, Acc: 0.3872, F1: 0.5582 || Edge_diff: 0.6403, Embed_diff: 0.6251, Input_diff: 1.0144 || Time: 0.6723s
# Epoch: 15 || Loss: 0.6561, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.6366, Embed_diff: 0.6138, Input_diff: 1.0143 || Time: 0.3146s
# Epoch: 16 || Loss: 0.6555, Acc: 0.3871, F1: 0.5582 || Edge_diff: 0.6342, Embed_diff: 0.6075, Input_diff: 1.0142 || Time: 0.3963s
# Epoch: 17 || Loss: 0.6529, Acc: 0.3872, F1: 0.5582 || Edge_diff: 0.6208, Embed_diff: 0.5968, Input_diff: 1.0140 || Time: 0.4043s
# Epoch: 18 || Loss: 0.6518, Acc: 0.3872, F1: 0.5582 || Edge_diff: 0.6127, Embed_diff: 0.5816, Input_diff: 1.0143 || Time: 0.4020s
# Epoch: 19 || Loss: 0.6510, Acc: 0.3872, F1: 0.5582 || Edge_diff: 0.6220, Embed_diff: 0.5790, Input_diff: 1.0140 || Time: 0.4070s
# Epoch: 20 || Loss: 0.6493, Acc: 0.3872, F1: 0.5582 || Edge_diff: 0.6045, Embed_diff: 0.5785, Input_diff: 1.0141 || Time: 0.4202s
# Epoch: 21 || Loss: 0.6478, Acc: 0.3875, F1: 0.5583 || Edge_diff: 0.6123, Embed_diff: 0.5728, Input_diff: 1.0139 || Time: 0.4186s
# Epoch: 22 || Loss: 0.6476, Acc: 0.3876, F1: 0.5584 || Edge_diff: 0.6059, Embed_diff: 0.5772, Input_diff: 1.0142 || Time: 0.4162s
# Epoch: 23 || Loss: 0.6473, Acc: 0.3877, F1: 0.5584 || Edge_diff: 0.6122, Embed_diff: 0.5811, Input_diff: 1.0142 || Time: 0.4147s
# Epoch: 24 || Loss: 0.6443, Acc: 0.3884, F1: 0.5587 || Edge_diff: 0.5884, Embed_diff: 0.5668, Input_diff: 1.0142 || Time: 0.4257s
# Epoch: 25 || Loss: 0.6460, Acc: 0.3885, F1: 0.5586 || Edge_diff: 0.6084, Embed_diff: 0.5572, Input_diff: 1.0140 || Time: 0.4201s
# Epoch: 26 || Loss: 0.6430, Acc: 0.3894, F1: 0.5591 || Edge_diff: 0.5876, Embed_diff: 0.5575, Input_diff: 1.0140 || Time: 0.4202s
# Epoch: 27 || Loss: 0.6441, Acc: 0.3888, F1: 0.5588 || Edge_diff: 0.5887, Embed_diff: 0.5549, Input_diff: 1.0137 || Time: 0.4701s
# Epoch: 28 || Loss: 0.6422, Acc: 0.3892, F1: 0.5590 || Edge_diff: 0.5897, Embed_diff: 0.5493, Input_diff: 1.0142 || Time: 0.4263s
# Epoch: 29 || Loss: 0.6405, Acc: 0.3901, F1: 0.5593 || Edge_diff: 0.5833, Embed_diff: 0.5469, Input_diff: 1.0140 || Time: 0.3426s
# Epoch: 30 || Loss: 0.6387, Acc: 0.3907, F1: 0.5596 || Edge_diff: 0.5756, Embed_diff: 0.5457, Input_diff: 1.0136 || Time: 0.4290s
# Epoch: 31 || Loss: 0.6389, Acc: 0.3905, F1: 0.5595 || Edge_diff: 0.5708, Embed_diff: 0.5455, Input_diff: 1.0137 || Time: 0.5849s
# Epoch: 32 || Loss: 0.6398, Acc: 0.3906, F1: 0.5595 || Edge_diff: 0.5766, Embed_diff: 0.5425, Input_diff: 1.0137 || Time: 0.7944s
# Epoch: 33 || Loss: 0.6390, Acc: 0.3914, F1: 0.5599 || Edge_diff: 0.5805, Embed_diff: 0.5410, Input_diff: 1.0140 || Time: 0.5951s
# Epoch: 34 || Loss: 0.6391, Acc: 0.3918, F1: 0.5601 || Edge_diff: 0.5869, Embed_diff: 0.5423, Input_diff: 1.0142 || Time: 0.7952s
# Epoch: 35 || Loss: 0.6387, Acc: 0.3903, F1: 0.5594 || Edge_diff: 0.5793, Embed_diff: 0.5445, Input_diff: 1.0141 || Time: 0.6085s
# Epoch: 36 || Loss: 0.6378, Acc: 0.3912, F1: 0.5598 || Edge_diff: 0.5780, Embed_diff: 0.5466, Input_diff: 1.0142 || Time: 0.7567s
# Epoch: 37 || Loss: 0.6371, Acc: 0.3922, F1: 0.5602 || Edge_diff: 0.5746, Embed_diff: 0.5423, Input_diff: 1.0141 || Time: 0.5206s
# Epoch: 38 || Loss: 0.6368, Acc: 0.3939, F1: 0.5609 || Edge_diff: 0.5754, Embed_diff: 0.5347, Input_diff: 1.0139 || Time: 0.3842s
# Epoch: 39 || Loss: 0.6363, Acc: 0.3935, F1: 0.5607 || Edge_diff: 0.5817, Embed_diff: 0.5327, Input_diff: 1.0139 || Time: 0.4192s
# Epoch: 40 || Loss: 0.6378, Acc: 0.3927, F1: 0.5604 || Edge_diff: 0.5783, Embed_diff: 0.5449, Input_diff: 1.0140 || Time: 0.4184s
# Epoch: 41 || Loss: 0.6351, Acc: 0.3940, F1: 0.5609 || Edge_diff: 0.5709, Embed_diff: 0.5346, Input_diff: 1.0142 || Time: 0.4260s
# Epoch: 42 || Loss: 0.6362, Acc: 0.3935, F1: 0.5607 || Edge_diff: 0.5741, Embed_diff: 0.5261, Input_diff: 1.0143 || Time: 0.4181s
# Epoch: 43 || Loss: 0.6366, Acc: 0.3936, F1: 0.5608 || Edge_diff: 0.5791, Embed_diff: 0.5279, Input_diff: 1.0144 || Time: 0.4214s
# Epoch: 44 || Loss: 0.6340, Acc: 0.3948, F1: 0.5613 || Edge_diff: 0.5693, Embed_diff: 0.5262, Input_diff: 1.0142 || Time: 0.4222s
# Epoch: 45 || Loss: 0.6341, Acc: 0.3953, F1: 0.5614 || Edge_diff: 0.5751, Embed_diff: 0.5298, Input_diff: 1.0142 || Time: 0.4180s
# Epoch: 46 || Loss: 0.6353, Acc: 0.3963, F1: 0.5618 || Edge_diff: 0.5742, Embed_diff: 0.5299, Input_diff: 1.0139 || Time: 0.4216s
# Epoch: 47 || Loss: 0.6326, Acc: 0.3970, F1: 0.5622 || Edge_diff: 0.5723, Embed_diff: 0.5312, Input_diff: 1.0142 || Time: 0.4222s
# Epoch: 48 || Loss: 0.6346, Acc: 0.3953, F1: 0.5614 || Edge_diff: 0.5862, Embed_diff: 0.5292, Input_diff: 1.0140 || Time: 0.4206s
# Epoch: 49 || Loss: 0.6338, Acc: 0.3975, F1: 0.5624 || Edge_diff: 0.5734, Embed_diff: 0.5324, Input_diff: 1.0143 || Time: 0.4206s
# Epoch: 50 || Loss: 0.6349, Acc: 0.3970, F1: 0.5620 || Edge_diff: 0.5794, Embed_diff: 0.5320, Input_diff: 1.0139 || Time: 0.4065s
# Epoch: 51 || Loss: 0.6368, Acc: 0.3953, F1: 0.5614 || Edge_diff: 0.5931, Embed_diff: 0.5423, Input_diff: 1.0142 || Time: 0.3634s
# Epoch: 52 || Loss: 0.6326, Acc: 0.3953, F1: 0.5615 || Edge_diff: 0.5746, Embed_diff: 0.5364, Input_diff: 1.0141 || Time: 0.4783s
# Epoch: 53 || Loss: 0.6356, Acc: 0.3958, F1: 0.5617 || Edge_diff: 0.5822, Embed_diff: 0.5317, Input_diff: 1.0141 || Time: 0.5781s
# Epoch: 54 || Loss: 0.6342, Acc: 0.3963, F1: 0.5618 || Edge_diff: 0.5828, Embed_diff: 0.5404, Input_diff: 1.0142 || Time: 0.7677s
# Epoch: 55 || Loss: 0.6354, Acc: 0.3952, F1: 0.5614 || Edge_diff: 0.5753, Embed_diff: 0.5245, Input_diff: 1.0144 || Time: 0.6387s
# Epoch: 56 || Loss: 0.6320, Acc: 0.3977, F1: 0.5624 || Edge_diff: 0.5830, Embed_diff: 0.5311, Input_diff: 1.0143 || Time: 0.7642s
# Epoch: 57 || Loss: 0.6322, Acc: 0.3978, F1: 0.5623 || Edge_diff: 0.5838, Embed_diff: 0.5458, Input_diff: 1.0143 || Time: 0.6062s
# Epoch: 58 || Loss: 0.6331, Acc: 0.3974, F1: 0.5623 || Edge_diff: 0.5859, Embed_diff: 0.5351, Input_diff: 1.0140 || Time: 0.7116s
# Epoch: 59 || Loss: 0.6338, Acc: 0.3954, F1: 0.5615 || Edge_diff: 0.5834, Embed_diff: 0.5408, Input_diff: 1.0140 || Time: 0.6613s
# Epoch: 60 || Loss: 0.6330, Acc: 0.3961, F1: 0.5617 || Edge_diff: 0.5691, Embed_diff: 0.5295, Input_diff: 1.0138 || Time: 0.3536s
# Epoch: 61 || Loss: 0.6338, Acc: 0.3955, F1: 0.5614 || Edge_diff: 0.5781, Embed_diff: 0.5291, Input_diff: 1.0144 || Time: 0.4240s
# Epoch: 62 || Loss: 0.6335, Acc: 0.3942, F1: 0.5610 || Edge_diff: 0.5775, Embed_diff: 0.5344, Input_diff: 1.0143 || Time: 0.4202s
# Epoch: 63 || Loss: 0.6323, Acc: 0.3963, F1: 0.5618 || Edge_diff: 0.5715, Embed_diff: 0.5297, Input_diff: 1.0144 || Time: 0.4158s
# Epoch: 64 || Loss: 0.6328, Acc: 0.3968, F1: 0.5620 || Edge_diff: 0.5782, Embed_diff: 0.5313, Input_diff: 1.0145 || Time: 0.4307s
# Epoch: 65 || Loss: 0.6343, Acc: 0.3948, F1: 0.5613 || Edge_diff: 0.5888, Embed_diff: 0.5364, Input_diff: 1.0144 || Time: 0.4178s
# Epoch: 66 || Loss: 0.6325, Acc: 0.3984, F1: 0.5625 || Edge_diff: 0.5800, Embed_diff: 0.5371, Input_diff: 1.0145 || Time: 0.4153s
# Epoch: 67 || Loss: 0.6334, Acc: 0.3942, F1: 0.5610 || Edge_diff: 0.5797, Embed_diff: 0.5359, Input_diff: 1.0144 || Time: 0.4121s
# Epoch: 68 || Loss: 0.6327, Acc: 0.3951, F1: 0.5610 || Edge_diff: 0.5885, Embed_diff: 0.5316, Input_diff: 1.0145 || Time: 0.4181s
# Epoch: 69 || Loss: 0.6320, Acc: 0.3959, F1: 0.5615 || Edge_diff: 0.5834, Embed_diff: 0.5346, Input_diff: 1.0144 || Time: 0.4131s
# Epoch: 70 || Loss: 0.6308, Acc: 0.3977, F1: 0.5625 || Edge_diff: 0.5809, Embed_diff: 0.5290, Input_diff: 1.0144 || Time: 0.4202s
# Epoch: 71 || Loss: 0.6345, Acc: 0.3944, F1: 0.5611 || Edge_diff: 0.5917, Embed_diff: 0.5404, Input_diff: 1.0143 || Time: 0.4162s
# Epoch: 72 || Loss: 0.6344, Acc: 0.3942, F1: 0.5608 || Edge_diff: 0.5890, Embed_diff: 0.5469, Input_diff: 1.0145 || Time: 0.4615s
# Epoch: 73 || Loss: 0.6331, Acc: 0.3953, F1: 0.5615 || Edge_diff: 0.5874, Embed_diff: 0.5386, Input_diff: 1.0147 || Time: 0.3923s
# Epoch: 74 || Loss: 0.6333, Acc: 0.3952, F1: 0.5614 || Edge_diff: 0.5859, Embed_diff: 0.5276, Input_diff: 1.0146 || Time: 0.3652s
# Epoch: 75 || Loss: 0.6317, Acc: 0.3957, F1: 0.5616 || Edge_diff: 0.5911, Embed_diff: 0.5408, Input_diff: 1.0144 || Time: 0.4390s
# Epoch: 76 || Loss: 0.6320, Acc: 0.3955, F1: 0.5614 || Edge_diff: 0.5819, Embed_diff: 0.5427, Input_diff: 1.0144 || Time: 0.7708s
# Epoch: 77 || Loss: 0.6326, Acc: 0.3972, F1: 0.5622 || Edge_diff: 0.5865, Embed_diff: 0.5340, Input_diff: 1.0145 || Time: 0.6881s
# Epoch: 78 || Loss: 0.6338, Acc: 0.3933, F1: 0.5606 || Edge_diff: 0.5902, Embed_diff: 0.5406, Input_diff: 1.0146 || Time: 0.7252s
# Epoch: 79 || Loss: 0.6321, Acc: 0.3953, F1: 0.5614 || Edge_diff: 0.5730, Embed_diff: 0.5371, Input_diff: 1.0143 || Time: 0.7163s
# Epoch: 80 || Loss: 0.6308, Acc: 0.3969, F1: 0.5621 || Edge_diff: 0.5745, Embed_diff: 0.5234, Input_diff: 1.0146 || Time: 0.6235s
# Epoch: 81 || Loss: 0.6324, Acc: 0.3966, F1: 0.5618 || Edge_diff: 0.5908, Embed_diff: 0.5319, Input_diff: 1.0145 || Time: 0.6922s
# Epoch: 82 || Loss: 0.6305, Acc: 0.3986, F1: 0.5628 || Edge_diff: 0.5752, Embed_diff: 0.5256, Input_diff: 1.0146 || Time: 0.4581s
# Epoch: 83 || Loss: 0.6315, Acc: 0.3980, F1: 0.5624 || Edge_diff: 0.5786, Embed_diff: 0.5319, Input_diff: 1.0148 || Time: 0.3818s
# Epoch: 84 || Loss: 0.6324, Acc: 0.3967, F1: 0.5621 || Edge_diff: 0.5856, Embed_diff: 0.5277, Input_diff: 1.0146 || Time: 0.4099s
# Epoch: 85 || Loss: 0.6315, Acc: 0.3965, F1: 0.5619 || Edge_diff: 0.5803, Embed_diff: 0.5338, Input_diff: 1.0145 || Time: 0.4053s
# Epoch: 86 || Loss: 0.6343, Acc: 0.3963, F1: 0.5618 || Edge_diff: 0.5940, Embed_diff: 0.5451, Input_diff: 1.0147 || Time: 0.4099s
# Epoch: 87 || Loss: 0.6308, Acc: 0.4020, F1: 0.5640 || Edge_diff: 0.5899, Embed_diff: 0.5429, Input_diff: 1.0141 || Time: 0.4084s
# Epoch: 88 || Loss: 0.6314, Acc: 0.3960, F1: 0.5615 || Edge_diff: 0.5802, Embed_diff: 0.5368, Input_diff: 1.0147 || Time: 0.4102s
# Epoch: 89 || Loss: 0.6323, Acc: 0.3963, F1: 0.5619 || Edge_diff: 0.5897, Embed_diff: 0.5326, Input_diff: 1.0144 || Time: 0.4110s
# Epoch: 90 || Loss: 0.6327, Acc: 0.3994, F1: 0.5632 || Edge_diff: 0.5786, Embed_diff: 0.5399, Input_diff: 1.0146 || Time: 0.4080s
# Epoch: 91 || Loss: 0.6329, Acc: 0.3979, F1: 0.5625 || Edge_diff: 0.5898, Embed_diff: 0.5382, Input_diff: 1.0142 || Time: 0.4096s
# Epoch: 92 || Loss: 0.6315, Acc: 0.3967, F1: 0.5620 || Edge_diff: 0.5751, Embed_diff: 0.5301, Input_diff: 1.0148 || Time: 0.4086s
# Epoch: 93 || Loss: 0.6314, Acc: 0.3982, F1: 0.5624 || Edge_diff: 0.5890, Embed_diff: 0.5393, Input_diff: 1.0143 || Time: 0.4095s
# Epoch: 94 || Loss: 0.6316, Acc: 0.4009, F1: 0.5638 || Edge_diff: 0.5907, Embed_diff: 0.5369, Input_diff: 1.0145 || Time: 0.3972s
# Epoch: 95 || Loss: 0.6326, Acc: 0.3963, F1: 0.5619 || Edge_diff: 0.5901, Embed_diff: 0.5279, Input_diff: 1.0149 || Time: 0.4147s
# Epoch: 96 || Loss: 0.6311, Acc: 0.3972, F1: 0.5622 || Edge_diff: 0.5789, Embed_diff: 0.5264, Input_diff: 1.0145 || Time: 0.4603s
# Epoch: 97 || Loss: 0.6326, Acc: 0.3950, F1: 0.5611 || Edge_diff: 0.5838, Embed_diff: 0.5408, Input_diff: 1.0146 || Time: 0.3126s
# Epoch: 98 || Loss: 0.6325, Acc: 0.3969, F1: 0.5621 || Edge_diff: 0.5869, Embed_diff: 0.5356, Input_diff: 1.0144 || Time: 0.4375s
# Epoch: 99 || Loss: 0.6329, Acc: 0.3949, F1: 0.5612 || Edge_diff: 0.5845, Embed_diff: 0.5380, Input_diff: 1.0148 || Time: 0.5535s
# Epoch: 100 || Loss: 0.6328, Acc: 0.3959, F1: 0.5615 || Edge_diff: 0.5765, Embed_diff: 0.5291, Input_diff: 1.0146 || Time: 0.7423s
# Epoch: 101 || Loss: 0.6318, Acc: 0.3959, F1: 0.5616 || Edge_diff: 0.5738, Embed_diff: 0.5253, Input_diff: 1.0145 || Time: 0.5924s
# Epoch: 102 || Loss: 0.6326, Acc: 0.3982, F1: 0.5625 || Edge_diff: 0.5949, Embed_diff: 0.5327, Input_diff: 1.0145 || Time: 0.7353s
# Epoch: 103 || Loss: 0.6327, Acc: 0.3971, F1: 0.5622 || Edge_diff: 0.5936, Embed_diff: 0.5385, Input_diff: 1.0147 || Time: 0.6378s
# Epoch: 104 || Loss: 0.6327, Acc: 0.3967, F1: 0.5620 || Edge_diff: 0.5823, Embed_diff: 0.5384, Input_diff: 1.0145 || Time: 0.6650s
# Epoch: 105 || Loss: 0.6331, Acc: 0.3956, F1: 0.5616 || Edge_diff: 0.5893, Embed_diff: 0.5388, Input_diff: 1.0145 || Time: 0.7037s
# Epoch: 106 || Loss: 0.6313, Acc: 0.3987, F1: 0.5627 || Edge_diff: 0.5892, Embed_diff: 0.5469, Input_diff: 1.0148 || Time: 0.3781s
# Epoch: 107 || Loss: 0.6314, Acc: 0.3974, F1: 0.5622 || Edge_diff: 0.5870, Embed_diff: 0.5329, Input_diff: 1.0145 || Time: 0.4067s
# Epoch: 108 || Loss: 0.6348, Acc: 0.3953, F1: 0.5615 || Edge_diff: 0.5978, Embed_diff: 0.5406, Input_diff: 1.0147 || Time: 0.4089s
# Epoch: 109 || Loss: 0.6332, Acc: 0.3958, F1: 0.5617 || Edge_diff: 0.5871, Embed_diff: 0.5399, Input_diff: 1.0146 || Time: 0.4091s
# Epoch: 110 || Loss: 0.6339, Acc: 0.3951, F1: 0.5614 || Edge_diff: 0.5854, Embed_diff: 0.5267, Input_diff: 1.0144 || Time: 0.4121s
# Epoch: 111 || Loss: 0.6325, Acc: 0.3975, F1: 0.5624 || Edge_diff: 0.5805, Embed_diff: 0.5328, Input_diff: 1.0145 || Time: 0.4091s
# Epoch: 112 || Loss: 0.6321, Acc: 0.3987, F1: 0.5628 || Edge_diff: 0.5794, Embed_diff: 0.5343, Input_diff: 1.0146 || Time: 0.4062s
# Epoch: 113 || Loss: 0.6314, Acc: 0.3980, F1: 0.5625 || Edge_diff: 0.5887, Embed_diff: 0.5289, Input_diff: 1.0142 || Time: 0.4096s
# Epoch: 114 || Loss: 0.6317, Acc: 0.3977, F1: 0.5623 || Edge_diff: 0.5845, Embed_diff: 0.5296, Input_diff: 1.0143 || Time: 0.4069s
# Epoch: 115 || Loss: 0.6346, Acc: 0.3968, F1: 0.5620 || Edge_diff: 0.5837, Embed_diff: 0.5307, Input_diff: 1.0145 || Time: 0.4118s
# Epoch: 116 || Loss: 0.6335, Acc: 0.3987, F1: 0.5628 || Edge_diff: 0.5805, Embed_diff: 0.5364, Input_diff: 1.0144 || Time: 0.4085s
# Epoch: 117 || Loss: 0.6321, Acc: 0.3994, F1: 0.5630 || Edge_diff: 0.5850, Embed_diff: 0.5235, Input_diff: 1.0141 || Time: 0.4049s
# Epoch: 118 || Loss: 0.6323, Acc: 0.3940, F1: 0.5609 || Edge_diff: 0.5760, Embed_diff: 0.5308, Input_diff: 1.0146 || Time: 0.4109s
# Epoch: 119 || Loss: 0.6327, Acc: 0.3981, F1: 0.5626 || Edge_diff: 0.5824, Embed_diff: 0.5381, Input_diff: 1.0144 || Time: 0.4103s
# Epoch: 120 || Loss: 0.6293, Acc: 0.3984, F1: 0.5624 || Edge_diff: 0.5758, Embed_diff: 0.5349, Input_diff: 1.0145 || Time: 0.4149s
# Epoch: 121 || Loss: 0.6326, Acc: 0.3977, F1: 0.5622 || Edge_diff: 0.5844, Embed_diff: 0.5296, Input_diff: 1.0144 || Time: 0.3782s
# Epoch: 122 || Loss: 0.6319, Acc: 0.3964, F1: 0.5619 || Edge_diff: 0.5869, Embed_diff: 0.5376, Input_diff: 1.0144 || Time: 0.4443s
# Epoch: 123 || Loss: 0.6351, Acc: 0.3953, F1: 0.5614 || Edge_diff: 0.5932, Embed_diff: 0.5391, Input_diff: 1.0143 || Time: 0.6577s
# Epoch: 124 || Loss: 0.6319, Acc: 0.3964, F1: 0.5619 || Edge_diff: 0.5826, Embed_diff: 0.5379, Input_diff: 1.0141 || Time: 0.7237s
# Epoch: 125 || Loss: 0.6305, Acc: 0.3972, F1: 0.5622 || Edge_diff: 0.5815, Embed_diff: 0.5273, Input_diff: 1.0145 || Time: 0.5949s
# Epoch: 126 || Loss: 0.6340, Acc: 0.3965, F1: 0.5619 || Edge_diff: 0.5851, Embed_diff: 0.5276, Input_diff: 1.0143 || Time: 0.7242s
# Epoch: 127 || Loss: 0.6310, Acc: 0.3978, F1: 0.5624 || Edge_diff: 0.5900, Embed_diff: 0.5404, Input_diff: 1.0146 || Time: 0.5704s
# Epoch: 128 || Loss: 0.6319, Acc: 0.3988, F1: 0.5629 || Edge_diff: 0.5794, Embed_diff: 0.5490, Input_diff: 1.0147 || Time: 0.6730s
# Epoch: 129 || Loss: 0.6315, Acc: 0.3986, F1: 0.5628 || Edge_diff: 0.5823, Embed_diff: 0.5383, Input_diff: 1.0145 || Time: 0.6720s
# Epoch: 130 || Loss: 0.6334, Acc: 0.3966, F1: 0.5618 || Edge_diff: 0.5869, Embed_diff: 0.5391, Input_diff: 1.0143 || Time: 0.3507s
# Epoch: 131 || Loss: 0.6324, Acc: 0.3970, F1: 0.5619 || Edge_diff: 0.5908, Embed_diff: 0.5403, Input_diff: 1.0145 || Time: 0.4210s
# Epoch: 132 || Loss: 0.6310, Acc: 0.4014, F1: 0.5638 || Edge_diff: 0.5880, Embed_diff: 0.5384, Input_diff: 1.0144 || Time: 0.4119s
# Epoch: 133 || Loss: 0.6320, Acc: 0.3998, F1: 0.5632 || Edge_diff: 0.5857, Embed_diff: 0.5405, Input_diff: 1.0146 || Time: 0.4116s
# Epoch: 134 || Loss: 0.6306, Acc: 0.3977, F1: 0.5624 || Edge_diff: 0.5823, Embed_diff: 0.5357, Input_diff: 1.0144 || Time: 0.4186s
# Epoch: 135 || Loss: 0.6320, Acc: 0.3953, F1: 0.5614 || Edge_diff: 0.5805, Embed_diff: 0.5273, Input_diff: 1.0146 || Time: 0.4132s
# Epoch: 136 || Loss: 0.6321, Acc: 0.3978, F1: 0.5624 || Edge_diff: 0.5970, Embed_diff: 0.5424, Input_diff: 1.0146 || Time: 0.4145s
# Epoch: 137 || Loss: 0.6325, Acc: 0.3968, F1: 0.5621 || Edge_diff: 0.5944, Embed_diff: 0.5396, Input_diff: 1.0144 || Time: 0.4165s
# Epoch: 138 || Loss: 0.6316, Acc: 0.3977, F1: 0.5623 || Edge_diff: 0.6011, Embed_diff: 0.5402, Input_diff: 1.0143 || Time: 0.4183s
# Epoch: 139 || Loss: 0.6327, Acc: 0.3945, F1: 0.5611 || Edge_diff: 0.5863, Embed_diff: 0.5499, Input_diff: 1.0145 || Time: 0.4131s
# Epoch: 140 || Loss: 0.6328, Acc: 0.3957, F1: 0.5616 || Edge_diff: 0.6038, Embed_diff: 0.5503, Input_diff: 1.0148 || Time: 0.4096s
# Epoch: 141 || Loss: 0.6304, Acc: 0.3989, F1: 0.5629 || Edge_diff: 0.5785, Embed_diff: 0.5398, Input_diff: 1.0144 || Time: 0.4630s
# Epoch: 142 || Loss: 0.6301, Acc: 0.3979, F1: 0.5625 || Edge_diff: 0.5898, Embed_diff: 0.5377, Input_diff: 1.0146 || Time: 0.4147s
# Epoch: 143 || Loss: 0.6312, Acc: 0.3947, F1: 0.5611 || Edge_diff: 0.5860, Embed_diff: 0.5363, Input_diff: 1.0147 || Time: 0.4132s
# Epoch: 144 || Loss: 0.6308, Acc: 0.3978, F1: 0.5625 || Edge_diff: 0.5846, Embed_diff: 0.5364, Input_diff: 1.0142 || Time: 0.3396s
# Epoch: 145 || Loss: 0.6293, Acc: 0.4015, F1: 0.5637 || Edge_diff: 0.5848, Embed_diff: 0.5383, Input_diff: 1.0145 || Time: 0.4270s
# Epoch: 146 || Loss: 0.6310, Acc: 0.3992, F1: 0.5629 || Edge_diff: 0.5840, Embed_diff: 0.5385, Input_diff: 1.0143 || Time: 0.5438s
# Epoch: 147 || Loss: 0.6323, Acc: 0.3992, F1: 0.5631 || Edge_diff: 0.5939, Embed_diff: 0.5380, Input_diff: 1.0144 || Time: 0.7591s
# Epoch: 148 || Loss: 0.6305, Acc: 0.4006, F1: 0.5635 || Edge_diff: 0.5867, Embed_diff: 0.5372, Input_diff: 1.0144 || Time: 0.6253s
# Epoch: 149 || Loss: 0.6314, Acc: 0.4003, F1: 0.5633 || Edge_diff: 0.5954, Embed_diff: 0.5297, Input_diff: 1.0146 || Time: 0.7638s
# Epoch: 150 || Loss: 0.6314, Acc: 0.3992, F1: 0.5629 || Edge_diff: 0.5809, Embed_diff: 0.5333, Input_diff: 1.0143 || Time: 0.6217s
# Epoch: 151 || Loss: 0.6326, Acc: 0.3983, F1: 0.5625 || Edge_diff: 0.5950, Embed_diff: 0.5371, Input_diff: 1.0145 || Time: 0.7024s
# Epoch: 152 || Loss: 0.6321, Acc: 0.3977, F1: 0.5624 || Edge_diff: 0.5936, Embed_diff: 0.5322, Input_diff: 1.0142 || Time: 0.7021s
# Epoch: 153 || Loss: 0.6322, Acc: 0.3983, F1: 0.5626 || Edge_diff: 0.5890, Embed_diff: 0.5374, Input_diff: 1.0144 || Time: 0.3408s
# Epoch: 154 || Loss: 0.6333, Acc: 0.3985, F1: 0.5628 || Edge_diff: 0.5940, Embed_diff: 0.5385, Input_diff: 1.0141 || Time: 0.4211s
# Epoch: 155 || Loss: 0.6301, Acc: 0.4011, F1: 0.5638 || Edge_diff: 0.5760, Embed_diff: 0.5330, Input_diff: 1.0144 || Time: 0.4144s
# Epoch: 156 || Loss: 0.6339, Acc: 0.3980, F1: 0.5626 || Edge_diff: 0.6004, Embed_diff: 0.5385, Input_diff: 1.0143 || Time: 0.4326s
# Epoch: 157 || Loss: 0.6327, Acc: 0.3991, F1: 0.5630 || Edge_diff: 0.5942, Embed_diff: 0.5485, Input_diff: 1.0146 || Time: 0.4168s
# Epoch: 158 || Loss: 0.6302, Acc: 0.4034, F1: 0.5646 || Edge_diff: 0.5926, Embed_diff: 0.5375, Input_diff: 1.0144 || Time: 0.4183s
# Epoch: 159 || Loss: 0.6305, Acc: 0.4005, F1: 0.5635 || Edge_diff: 0.5784, Embed_diff: 0.5266, Input_diff: 1.0145 || Time: 0.4168s
# Epoch: 160 || Loss: 0.6327, Acc: 0.3986, F1: 0.5628 || Edge_diff: 0.5881, Embed_diff: 0.5424, Input_diff: 1.0150 || Time: 0.4174s
# Epoch: 161 || Loss: 0.6315, Acc: 0.3971, F1: 0.5622 || Edge_diff: 0.5839, Embed_diff: 0.5368, Input_diff: 1.0143 || Time: 0.4190s
# Epoch: 162 || Loss: 0.6314, Acc: 0.4043, F1: 0.5650 || Edge_diff: 0.5889, Embed_diff: 0.5364, Input_diff: 1.0146 || Time: 0.4148s
# Epoch: 163 || Loss: 0.6323, Acc: 0.4001, F1: 0.5633 || Edge_diff: 0.5956, Embed_diff: 0.5490, Input_diff: 1.0147 || Time: 0.4192s
# Epoch: 164 || Loss: 0.6319, Acc: 0.3989, F1: 0.5628 || Edge_diff: 0.5828, Embed_diff: 0.5412, Input_diff: 1.0141 || Time: 0.4146s
# Epoch: 165 || Loss: 0.6311, Acc: 0.3986, F1: 0.5628 || Edge_diff: 0.5871, Embed_diff: 0.5433, Input_diff: 1.0144 || Time: 0.4639s
# Epoch: 166 || Loss: 0.6333, Acc: 0.4000, F1: 0.5633 || Edge_diff: 0.5852, Embed_diff: 0.5365, Input_diff: 1.0146 || Time: 0.4172s
# Epoch: 167 || Loss: 0.6335, Acc: 0.4012, F1: 0.5637 || Edge_diff: 0.5903, Embed_diff: 0.5392, Input_diff: 1.0143 || Time: 0.3294s
# Epoch: 168 || Loss: 0.6327, Acc: 0.4015, F1: 0.5638 || Edge_diff: 0.5967, Embed_diff: 0.5380, Input_diff: 1.0141 || Time: 0.4462s
# Epoch: 169 || Loss: 0.6317, Acc: 0.3964, F1: 0.5619 || Edge_diff: 0.5776, Embed_diff: 0.5329, Input_diff: 1.0145 || Time: 0.7154s
# Epoch: 170 || Loss: 0.6322, Acc: 0.3967, F1: 0.5619 || Edge_diff: 0.5886, Embed_diff: 0.5395, Input_diff: 1.0143 || Time: 0.7468s
# Epoch: 171 || Loss: 0.6316, Acc: 0.3966, F1: 0.5620 || Edge_diff: 0.5882, Embed_diff: 0.5368, Input_diff: 1.0143 || Time: 0.6659s
# Epoch: 172 || Loss: 0.6307, Acc: 0.3998, F1: 0.5632 || Edge_diff: 0.5816, Embed_diff: 0.5355, Input_diff: 1.0146 || Time: 0.7296s
# Epoch: 173 || Loss: 0.6316, Acc: 0.3979, F1: 0.5624 || Edge_diff: 0.5834, Embed_diff: 0.5487, Input_diff: 1.0145 || Time: 0.5708s
# Epoch: 174 || Loss: 0.6314, Acc: 0.3994, F1: 0.5631 || Edge_diff: 0.5784, Embed_diff: 0.5474, Input_diff: 1.0142 || Time: 0.7036s
# Epoch: 175 || Loss: 0.6328, Acc: 0.3967, F1: 0.5621 || Edge_diff: 0.5932, Embed_diff: 0.5382, Input_diff: 1.0143 || Time: 0.5820s
# Epoch: 176 || Loss: 0.6304, Acc: 0.3982, F1: 0.5625 || Edge_diff: 0.5781, Embed_diff: 0.5355, Input_diff: 1.0147 || Time: 0.3751s
# Epoch: 177 || Loss: 0.6319, Acc: 0.3990, F1: 0.5629 || Edge_diff: 0.5939, Embed_diff: 0.5370, Input_diff: 1.0145 || Time: 0.4147s
# Epoch: 178 || Loss: 0.6321, Acc: 0.3983, F1: 0.5626 || Edge_diff: 0.5918, Embed_diff: 0.5494, Input_diff: 1.0140 || Time: 0.4187s
# Epoch: 179 || Loss: 0.6332, Acc: 0.3966, F1: 0.5620 || Edge_diff: 0.5911, Embed_diff: 0.5466, Input_diff: 1.0144 || Time: 0.4212s
# Epoch: 180 || Loss: 0.6319, Acc: 0.3977, F1: 0.5625 || Edge_diff: 0.5972, Embed_diff: 0.5395, Input_diff: 1.0143 || Time: 0.4215s
# Epoch: 181 || Loss: 0.6310, Acc: 0.3989, F1: 0.5628 || Edge_diff: 0.5779, Embed_diff: 0.5305, Input_diff: 1.0144 || Time: 0.4254s
# Epoch: 182 || Loss: 0.6324, Acc: 0.3970, F1: 0.5622 || Edge_diff: 0.5931, Embed_diff: 0.5440, Input_diff: 1.0145 || Time: 0.4166s
# Epoch: 183 || Loss: 0.6317, Acc: 0.4000, F1: 0.5633 || Edge_diff: 0.5859, Embed_diff: 0.5441, Input_diff: 1.0141 || Time: 0.4050s
# Epoch: 184 || Loss: 0.6329, Acc: 0.4010, F1: 0.5637 || Edge_diff: 0.5843, Embed_diff: 0.5301, Input_diff: 1.0141 || Time: 0.4157s
# Epoch: 185 || Loss: 0.6328, Acc: 0.3991, F1: 0.5630 || Edge_diff: 0.5833, Embed_diff: 0.5376, Input_diff: 1.0143 || Time: 0.4218s
# Epoch: 186 || Loss: 0.6318, Acc: 0.3999, F1: 0.5632 || Edge_diff: 0.5801, Embed_diff: 0.5398, Input_diff: 1.0145 || Time: 0.4257s
# Epoch: 187 || Loss: 0.6307, Acc: 0.3999, F1: 0.5632 || Edge_diff: 0.5874, Embed_diff: 0.5327, Input_diff: 1.0143 || Time: 0.4135s
# Epoch: 188 || Loss: 0.6333, Acc: 0.3988, F1: 0.5629 || Edge_diff: 0.6048, Embed_diff: 0.5407, Input_diff: 1.0144 || Time: 0.4165s
# Epoch: 189 || Loss: 0.6329, Acc: 0.3983, F1: 0.5626 || Edge_diff: 0.5870, Embed_diff: 0.5456, Input_diff: 1.0147 || Time: 0.4018s
# Epoch: 190 || Loss: 0.6317, Acc: 0.3982, F1: 0.5625 || Edge_diff: 0.5858, Embed_diff: 0.5415, Input_diff: 1.0146 || Time: 0.4306s
# Epoch: 191 || Loss: 0.6340, Acc: 0.4013, F1: 0.5639 || Edge_diff: 0.5988, Embed_diff: 0.5543, Input_diff: 1.0142 || Time: 0.4755s
# Epoch: 192 || Loss: 0.6328, Acc: 0.4020, F1: 0.5640 || Edge_diff: 0.5932, Embed_diff: 0.5506, Input_diff: 1.0148 || Time: 0.7707s
# Epoch: 193 || Loss: 0.6305, Acc: 0.4035, F1: 0.5647 || Edge_diff: 0.5794, Embed_diff: 0.5329, Input_diff: 1.0144 || Time: 0.6344s
# Epoch: 194 || Loss: 0.6317, Acc: 0.4011, F1: 0.5637 || Edge_diff: 0.5809, Embed_diff: 0.5420, Input_diff: 1.0144 || Time: 0.7526s
# Epoch: 195 || Loss: 0.6323, Acc: 0.4009, F1: 0.5637 || Edge_diff: 0.6006, Embed_diff: 0.5383, Input_diff: 1.0142 || Time: 0.6918s
# Optimization Finished!
# Total time elapsed: 96.7898s
# Loading 145th epoch
# Loss: 0.6024, Acc: 0.5163, F1: 0.6724

# %%
plt.plot(loss_values)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Curve')
# Out:
# Text(0.5, 1.0, 'Training Loss Curve')

# %%
plt.plot(edge_diffs)
plt.xlabel('Epoch')
plt.ylabel('Edge-wise Distance')
plt.title('Training Edge-wise Distance Curve')
# Out:
# Text(0.5, 1.0, 'Training Edge-wise Distance Curve')

# %%
plt.plot(embed_diffs)
plt.xlabel('Epoch')
plt.ylabel('Change in Last/Curr Embedding')
plt.title('Change in Embedding Curve')
# Out:
# Text(0.5, 1.0, 'Change in Embedding Curve')

# %%
plt.plot(input_diffs)
plt.xlabel('Epoch')
plt.ylabel('Change in Input/Output')
plt.title('Change in Input/Output Curve')
# Out:
# Text(0.5, 1.0, 'Change in Input/Output Curve')
